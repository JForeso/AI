# %%
import pandas as pd
import seaborn as sns
import requests

# %%
# Now Playing Endpoint
url = "https://api.themoviedb.org/3/movie/now_playing?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI4Nzk4M2ZiZTk3Njk4OGE5ZTIyMzMwZWJmMDMwYTFhZSIsIm5iZiI6MTcyNzk3MTk0OS45MTA1MjcsInN1YiI6IjYzNzQyNGMyNDZlNzVmMDA5MGE3YmRhYyIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.ZsTpMVaVlF8ioN3-WiYEatqWmnGQhCKlILQv4Xi6Eec"
}

response = requests.get(url, headers=headers)
response = response.json()
now = pd.DataFrame(response["results"])
now.head()
# Out:
#    adult                     backdrop_path         genre_ids       id  \
# 0  False  /417tYZ4XUyJrtyZXj7HpvWf1E8f.jpg  [16, 878, 10751]  1184918
# 1  False  /7h6TqPB3ESmjuVbxCxAeB1c9OB1.jpg     [27, 18, 878]   933260
# 2  False  /4KHEK6AQFHhv4TDtL3KLReePB05.jpg      [28, 27, 53]  1029235
# 3  False  /eQEgKIRF7KeVGBQ8IYcklpU8RPf.jpg          [27, 53]  1034541
# 4  False  /3V4kLQg0kSqPLctI5ziYWabAZYF.jpg     [28, 878, 12]   912649
#
#   original_language         original_title  \
# 0                en         The Wild Robot
# 1                en          The Substance
# 2                en                 Azrael
# 3                en            Terrifier 3
# 4                en  Venom: The Last Dance
#
#                                             overview  popularity  \
# 0  After a shipwreck, an intelligent robot called...    5200.959
# 1  Have you ever dreamt of a better version of yo...    3159.484
# 2  In a world where no one speaks, a devout femal...    1635.458
# 3  Five years after surviving Art the Clown's Hal...    1681.930
# 4  Eddie and Venom are on the run. Hunted by both...    1678.855
#
#                         poster_path release_date                  title  \
# 0  /wTnV3PCVW5O92JMrFvvrRcV39RU.jpg   2024-09-12         The Wild Robot
# 1  /lqoMzCcZYEFK729d6qzt349fB4o.jpg   2024-09-07          The Substance
# 2  /qpdFKDvJS7oLKTcBLXOaMwUESbs.jpg   2024-09-27                 Azrael
# 3  /63xYQj1BwRFielxsBDXvHIJyXVm.jpg   2024-10-09            Terrifier 3
# 4  /k42Owka8v91trK1qMYwCQCNwJKr.jpg   2024-10-22  Venom: The Last Dance
#
#    video  vote_average  vote_count
# 0  False         8.660        1284
# 1  False         7.300         797
# 2  False         6.095          84
# 3  False         7.044         103
# 4  False         7.300          19

# %%
# Popular

url = "https://api.themoviedb.org/3/movie/popular?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI4Nzk4M2ZiZTk3Njk4OGE5ZTIyMzMwZWJmMDMwYTFhZSIsIm5iZiI6MTcyNzk3MTk0OS45MTA1MjcsInN1YiI6IjYzNzQyNGMyNDZlNzVmMDA5MGE3YmRhYyIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.ZsTpMVaVlF8ioN3-WiYEatqWmnGQhCKlILQv4Xi6Eec"
}

response = requests.get(url, headers=headers)
response = response.json()
pop = pd.DataFrame(response["results"])

# %%
# Top Rated

url = "https://api.themoviedb.org/3/movie/top_rated?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI4Nzk4M2ZiZTk3Njk4OGE5ZTIyMzMwZWJmMDMwYTFhZSIsIm5iZiI6MTcyNzk3MTk0OS45MTA1MjcsInN1YiI6IjYzNzQyNGMyNDZlNzVmMDA5MGE3YmRhYyIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.ZsTpMVaVlF8ioN3-WiYEatqWmnGQhCKlILQv4Xi6Eec"
}

response = requests.get(url, headers=headers)
response = response.json()
top = pd.DataFrame(response["results"])

# %%
# Upcoming
url = "https://api.themoviedb.org/3/movie/upcoming?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI4Nzk4M2ZiZTk3Njk4OGE5ZTIyMzMwZWJmMDMwYTFhZSIsIm5iZiI6MTcyNzk3MTk0OS45MTA1MjcsInN1YiI6IjYzNzQyNGMyNDZlNzVmMDA5MGE3YmRhYyIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.ZsTpMVaVlF8ioN3-WiYEatqWmnGQhCKlILQv4Xi6Eec"
}

response = requests.get(url, headers=headers)
response = response.json()
up = pd.DataFrame(response["results"])

# %%
df = pd.concat([now, pop, top, up])

# %%
df.drop_duplicates(subset=['id'], inplace=True)

# %%
def get_revenue_budget(df):
    '''
    Uses the movie id to get data from the "Details" endpoint
    Returns a dataframe of revenue and budget data
    '''
    data = {
        "id":[],
        "budget": [],
        "revenue": []
    }

    for i in df["id"]:
        data["id"].append(i)
        url = "https://api.themoviedb.org/3/movie/"+str(i)+"?language=en-US"

        headers = {
            "accept": "application/json",
            "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI4Nzk4M2ZiZTk3Njk4OGE5ZTIyMzMwZWJmMDMwYTFhZSIsIm5iZiI6MTcyNzk3MTk0OS45MTA1MjcsInN1YiI6IjYzNzQyNGMyNDZlNzVmMDA5MGE3YmRhYyIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.ZsTpMVaVlF8ioN3-WiYEatqWmnGQhCKlILQv4Xi6Eec"
        }

        response = requests.get(url, headers=headers)
        response = response.json()
        data["budget"].append(response["budget"])
        data["revenue"].append(response["revenue"])
        
    return pd.DataFrame(data)

# %%
money_df = get_revenue_budget(df)

# %%
money_df.head()
# Out:
#         id     budget    revenue
# 0  1184918   78000000  197296880
# 1   933260   17500000   29106531
# 2  1029235   12000000          0
# 3  1034541    2000000   41643487
# 4   912649  110000000          0

# %%
df = pd.merge(df, money_df, how="inner", on="id")

# %%
df.head()
# Out:
#    adult                     backdrop_path         genre_ids       id  \
# 0  False  /417tYZ4XUyJrtyZXj7HpvWf1E8f.jpg  [16, 878, 10751]  1184918
# 1  False  /7h6TqPB3ESmjuVbxCxAeB1c9OB1.jpg     [27, 18, 878]   933260
# 2  False  /4KHEK6AQFHhv4TDtL3KLReePB05.jpg      [28, 27, 53]  1029235
# 3  False  /eQEgKIRF7KeVGBQ8IYcklpU8RPf.jpg          [27, 53]  1034541
# 4  False  /3V4kLQg0kSqPLctI5ziYWabAZYF.jpg     [28, 878, 12]   912649
#
#   original_language         original_title  \
# 0                en         The Wild Robot
# 1                en          The Substance
# 2                en                 Azrael
# 3                en            Terrifier 3
# 4                en  Venom: The Last Dance
#
#                                             overview  popularity  \
# 0  After a shipwreck, an intelligent robot called...    5200.959
# 1  Have you ever dreamt of a better version of yo...    3159.484
# 2  In a world where no one speaks, a devout femal...    1635.458
# 3  Five years after surviving Art the Clown's Hal...    1681.930
# 4  Eddie and Venom are on the run. Hunted by both...    1678.855
#
#                         poster_path release_date                  title  \
# 0  /wTnV3PCVW5O92JMrFvvrRcV39RU.jpg   2024-09-12         The Wild Robot
# 1  /lqoMzCcZYEFK729d6qzt349fB4o.jpg   2024-09-07          The Substance
# 2  /qpdFKDvJS7oLKTcBLXOaMwUESbs.jpg   2024-09-27                 Azrael
# 3  /63xYQj1BwRFielxsBDXvHIJyXVm.jpg   2024-10-09            Terrifier 3
# 4  /k42Owka8v91trK1qMYwCQCNwJKr.jpg   2024-10-22  Venom: The Last Dance
#
#    video  vote_average  vote_count     budget    revenue
# 0  False         8.660        1284   78000000  197296880
# 1  False         7.300         797   17500000   29106531
# 2  False         6.095          84   12000000          0
# 3  False         7.044         103    2000000   41643487
# 4  False         7.300          19  110000000          0

# %%
sns.regplot(data=df, x="budget", y="revenue")
# Out:
# <AxesSubplot:xlabel='budget', ylabel='revenue'>

# %%
import numpy as np
df["revenue_sqrt"] = np.sqrt(df["revenue"])
df["budget_sqrt"] = np.sqrt(df["budget"])

# %%
df.head()
# Out:
#    adult                     backdrop_path         genre_ids       id  \
# 0  False  /417tYZ4XUyJrtyZXj7HpvWf1E8f.jpg  [16, 878, 10751]  1184918
# 1  False  /7h6TqPB3ESmjuVbxCxAeB1c9OB1.jpg     [27, 18, 878]   933260
# 2  False  /4KHEK6AQFHhv4TDtL3KLReePB05.jpg      [28, 27, 53]  1029235
# 3  False  /eQEgKIRF7KeVGBQ8IYcklpU8RPf.jpg          [27, 53]  1034541
# 4  False  /3V4kLQg0kSqPLctI5ziYWabAZYF.jpg     [28, 878, 12]   912649
#
#   original_language         original_title  \
# 0                en         The Wild Robot
# 1                en          The Substance
# 2                en                 Azrael
# 3                en            Terrifier 3
# 4                en  Venom: The Last Dance
#
#                                             overview  popularity  \
# 0  After a shipwreck, an intelligent robot called...    5200.959
# 1  Have you ever dreamt of a better version of yo...    3159.484
# 2  In a world where no one speaks, a devout femal...    1635.458
# 3  Five years after surviving Art the Clown's Hal...    1681.930
# 4  Eddie and Venom are on the run. Hunted by both...    1678.855
#
#                         poster_path release_date                  title  \
# 0  /wTnV3PCVW5O92JMrFvvrRcV39RU.jpg   2024-09-12         The Wild Robot
# 1  /lqoMzCcZYEFK729d6qzt349fB4o.jpg   2024-09-07          The Substance
# 2  /qpdFKDvJS7oLKTcBLXOaMwUESbs.jpg   2024-09-27                 Azrael
# 3  /63xYQj1BwRFielxsBDXvHIJyXVm.jpg   2024-10-09            Terrifier 3
# 4  /k42Owka8v91trK1qMYwCQCNwJKr.jpg   2024-10-22  Venom: The Last Dance
#
#    video  vote_average  vote_count     budget    revenue  revenue_sqrt  \
# 0  False         8.660        1284   78000000  197296880  14046.240778
# 1  False         7.300         797   17500000   29106531   5395.046895
# 2  False         6.095          84   12000000          0      0.000000
# 3  False         7.044         103    2000000   41643487   6453.176505
# 4  False         7.300          19  110000000          0      0.000000
#
#     budget_sqrt
# 0   8831.760866
# 1   4183.300133
# 2   3464.101615
# 3   1414.213562
# 4  10488.088482

# %%
def get_best_fit(data, x, y):
    '''
    Determines the slope (m) and intercept (b) of the best fit line
    for two variables, x and y.
    '''
    m = 0
    for count in range(100):
        m = m + 1
        b = 0

        # Calculate residuals (y = mx+b)
        res = 0
        for i in range(len(data)):
            pred_y = (m * data.loc[i][x]) + b
            act_y = data.loc[i][y]
            temp = act_y - pred_y 
            temp = temp ** 2
            res = res + temp
        print(res)
    return (m, b, res)

# %%
get_best_fit(df, "budget_sqrt", "revenue_sqrt")
# Out:
# 5239105482.848893
# 3812502248.6977873
# 6705250516.54668
# 13917350286.395573
# 25448801558.244473
# 41299604332.09336
# 61469758607.94225
# 85959264385.79115
# 114768121665.64005
# 147896330447.48892
# 185343890731.33783
# 227110802517.1867
# 273197065805.0356
# 323602680594.8845
# 378327646886.7334
# 437371964680.58246
# 500735633976.43115
# 568418654774.28
# 640421027074.1289
# 716742750875.9777
# 797383826179.8269
# 882344252985.6754
# 971624031293.5248
# 1065223161103.3734
# 1163141642415.222
# 1265379475229.0713
# 1371936659544.9202
# 1482813195362.769
# 1598009082682.618
# 1717524321504.4663
# 1841358911828.3154
# 1969512853654.1643
# 2101986146982.0134
# 2238778791811.863
# 2379890788143.712
# 2525322135977.5605
# 2675072835313.409
# 2829142886151.258
# 2987532288491.107
# 3150241042332.956
# 3317269147676.804
# 3488616604522.6533
# 3664283412870.5024
# 3844269572720.352
# 4028575084072.199
# 4217199946926.049
# 4410144161281.898
# 4607407727139.746
# 4808990644499.597
# 5014892913361.445
# 5225114533725.293
# 5439655505591.142
# 5658515828958.993
# 5881695503828.84
# 6109194530200.689
# 6341012908074.539
# 6577150637450.389
# 6817607718328.233
# 7062384150708.086
# 7311479934589.935
# 7564895069973.783
# 7822629556859.629
# 8084683395247.48
# 8351056585137.329
# 8621749126529.179
# 8896761019423.027
# 9176092263818.877
# 9459742859716.725
# 9747712807116.57
# 10040002106018.424
# 10336610756422.27
# 10637538758328.12
# 10942786111735.967
# 11252352816645.812
# 11566238873057.672
# 11884444280971.516
# 12206969040387.365
# 12533813151305.215
# 12864976613725.064
# 13200459427646.908
# 13540261593070.762
# 13884383109996.61
# 14232823978424.457
# 14585584198354.305
# 14942663769786.156
# 15304062692720.006
# 15669780967155.857
# 16039818593093.701
# 16414175570533.555
# 16792851899475.396
# 17175847579919.25
# 17563162611865.096
# 17954796995312.94
# 18350750730262.793
# 18751023816714.65
# 19155616254668.492
# 19564528044124.34
# 19977759185082.19
# 20395309677542.04
# 20817179521503.89
# (100, 0, 20817179521503.89)

# %%
# Luis: y = 1.78x + 1279 
# Caleb: y = 0.724x + 0.783
# Zach: y = 1.896x + 1028.934

# Luis
rev1 = 100 * 5000000

# Caleb
rev2 = 0.724*5000000 + 0.783

# Zach
rev3 = 1.896*5000000 + 1028.934

# %%
df.head()
# Out:
#    adult                     backdrop_path         genre_ids       id  \
# 0  False  /417tYZ4XUyJrtyZXj7HpvWf1E8f.jpg  [16, 878, 10751]  1184918
# 1  False  /7h6TqPB3ESmjuVbxCxAeB1c9OB1.jpg     [27, 18, 878]   933260
# 2  False  /4KHEK6AQFHhv4TDtL3KLReePB05.jpg      [28, 27, 53]  1029235
# 3  False  /eQEgKIRF7KeVGBQ8IYcklpU8RPf.jpg          [27, 53]  1034541
# 4  False  /3V4kLQg0kSqPLctI5ziYWabAZYF.jpg     [28, 878, 12]   912649
#
#   original_language         original_title  \
# 0                en         The Wild Robot
# 1                en          The Substance
# 2                en                 Azrael
# 3                en            Terrifier 3
# 4                en  Venom: The Last Dance
#
#                                             overview  popularity  \
# 0  After a shipwreck, an intelligent robot called...    5200.959
# 1  Have you ever dreamt of a better version of yo...    3159.484
# 2  In a world where no one speaks, a devout femal...    1635.458
# 3  Five years after surviving Art the Clown's Hal...    1681.930
# 4  Eddie and Venom are on the run. Hunted by both...    1678.855
#
#                         poster_path release_date                  title  \
# 0  /wTnV3PCVW5O92JMrFvvrRcV39RU.jpg   2024-09-12         The Wild Robot
# 1  /lqoMzCcZYEFK729d6qzt349fB4o.jpg   2024-09-07          The Substance
# 2  /qpdFKDvJS7oLKTcBLXOaMwUESbs.jpg   2024-09-27                 Azrael
# 3  /63xYQj1BwRFielxsBDXvHIJyXVm.jpg   2024-10-09            Terrifier 3
# 4  /k42Owka8v91trK1qMYwCQCNwJKr.jpg   2024-10-22  Venom: The Last Dance
#
#    video  vote_average  vote_count     budget    revenue  revenue_sqrt  \
# 0  False         8.660        1284   78000000  197296880  14046.240778
# 1  False         7.300         797   17500000   29106531   5395.046895
# 2  False         6.095          84   12000000          0      0.000000
# 3  False         7.044         103    2000000   41643487   6453.176505
# 4  False         7.300          19  110000000          0      0.000000
#
#     budget_sqrt
# 0   8831.760866
# 1   4183.300133
# 2   3464.101615
# 3   1414.213562
# 4  10488.088482

# %%
print(rev1, rev2, rev3)
# Out:
# 500000000 3620000.783 9481028.934

# %%
# Step 1: Calculate the Sum of Squares Total; this is (y - mean of y)
# Step 2: Calculate the Sum of Squares Residuals; this is (y predicted - y actual)
# Step 3: R2 = 1 - (SSR / SST)

def get_r2(df, x, y, m, b):
    mean = df[y].mean()
    total_sst = 0
    # Calculate SST
    for value in df[y]:
        difference = (value - mean)
        squared = difference ** 2
        total_sst += squared
    
    total_ssr = 0
    # Calculate SSR
    for i in range(len(df)):
        predicted = (m * df.loc[i][x]) + b
        difference = predicted - df.loc[i][y]
        squared = difference ** 2
        total_ssr += squared
    
    r2 = 1 - (total_ssr / total_sst)
    return r2

# %%
get_r2(df, "budget", "revenue", 1.896, 1028.934)
# Out:
# 0.18038445643262735

# %%
# Luis - r2 0.21
# Caleb - check
# Zach - r2 0.24


# The r2 value should be close to 1 for a linear model to be seen as accurate!

# %%
# Popular 
action = []
romance = []
url = "https://api.themoviedb.org/3/movie/popular?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI4Nzk4M2ZiZTk3Njk4OGE5ZTIyMzMwZWJmMDMwYTFhZSIsIm5iZiI6MTcyNzk3MTk0OS45MTA1MjcsInN1YiI6IjYzNzQyNGMyNDZlNzVmMDA5MGE3YmRhYyIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.ZsTpMVaVlF8ioN3-WiYEatqWmnGQhCKlILQv4Xi6Eec"
}
response = requests.get(url, headers=headers)
response = response.json()["results"]
for i in range(len(response)):
    genres = response[i]["genre_ids"]
    if 28 in genres:
        action.append(response[i])
    if 10749 in genres:
        romance.append(response[i])
action = pd.DataFrame(action)
romance = pd.DataFrame(romance)

# %%
print(len(action), len(romance))
# Out:
# 9 1

# %%
page = 2
while len(action) < 100 or len(romance) < 100:
    url = "https://api.themoviedb.org/3/movie/popular?language=en-US&page=" + str(page)

    headers = {
        "accept": "application/json",
        "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI4Nzk4M2ZiZTk3Njk4OGE5ZTIyMzMwZWJmMDMwYTFhZSIsIm5iZiI6MTcyNzk3MTk0OS45MTA1MjcsInN1YiI6IjYzNzQyNGMyNDZlNzVmMDA5MGE3YmRhYyIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.ZsTpMVaVlF8ioN3-WiYEatqWmnGQhCKlILQv4Xi6Eec"
    }
    response = requests.get(url, headers=headers)
    response = response.json()["results"]
    page += 1
    for i in range(len(response)):
        genres = response[i]["genre_ids"]
        temp = pd.DataFrame(response[i])
        if 28 in genres:
            action = pd.concat([temp, action], ignore_index=True)
        if 10749 in genres:
            romance = pd.concat([temp, romance], ignore_index=True)

# %%
print(len(action), len(romance))
action = action[:100]
romance = romance[:100]
# Out:
# 359 102

# %%
print(len(action), len(romance))
# Out:
# 100 100

# %%
romance
# Out:
#     adult                     backdrop_path genre_ids       id  \
# 0   False  /7VEUOEfRzzrQfWddlIyLUKvh6Nf.jpg        12   447277
# 1   False  /7VEUOEfRzzrQfWddlIyLUKvh6Nf.jpg     10751   447277
# 2   False  /7VEUOEfRzzrQfWddlIyLUKvh6Nf.jpg        14   447277
# 3   False  /7VEUOEfRzzrQfWddlIyLUKvh6Nf.jpg     10749   447277
# 4   False  /iQslVnGFJWQzz5kGTvOhU85656f.jpg        18  1156593
# ..    ...                               ...       ...      ...
# 95  False  /9msuazXGWAyl7vhxVFU7e7Bb5Ik.jpg     10749   179387
# 96  False  /zAqBIeO71BFL7bAtP5TFzVjVamy.jpg     10749  1079091
# 97  False  /zAqBIeO71BFL7bAtP5TFzVjVamy.jpg        18  1079091
# 98  False  /l0Y9OzRWKmlzZcGy4olKaOPXsru.jpg     10749     3933
# 99  False  /l0Y9OzRWKmlzZcGy4olKaOPXsru.jpg        14     3933
#
#    original_language      original_title  \
# 0                 en  The Little Mermaid
# 1                 en  The Little Mermaid
# 2                 en  The Little Mermaid
# 3                 en  The Little Mermaid
# 4                 es          Culpa tuya
# ..               ...                 ...
# 95                tl      Heavenly Touch
# 96                en     It Ends with Us
# 97                en     It Ends with Us
# 98                en        Corpse Bride
# 99                en        Corpse Bride
#
#                                              overview  popularity  \
# 0   The youngest of King Triton’s daughters, and t...     101.114
# 1   The youngest of King Triton’s daughters, and t...     101.114
# 2   The youngest of King Triton’s daughters, and t...     101.114
# 3   The youngest of King Triton’s daughters, and t...     101.114
# 4   The love between Noah and Nick seems unbreakab...     104.631
# ..                                                ...         ...
# 95  Jonard is having trouble making ends meet. His...     479.316
# 96  When a woman's first love suddenly reenters he...     799.043
# 97  When a woman's first love suddenly reenters he...     799.043
# 98  Set in a 19th-century European village, this s...     617.308
# 99  Set in a 19th-century European village, this s...     617.308
#
#                          poster_path release_date               title  video  \
# 0   /ym1dxyOk4jFcSl4Q2zmRrA5BEEN.jpg   2023-05-18  The Little Mermaid  False
# 1   /ym1dxyOk4jFcSl4Q2zmRrA5BEEN.jpg   2023-05-18  The Little Mermaid  False
# 2   /ym1dxyOk4jFcSl4Q2zmRrA5BEEN.jpg   2023-05-18  The Little Mermaid  False
# 3   /ym1dxyOk4jFcSl4Q2zmRrA5BEEN.jpg   2023-05-18  The Little Mermaid  False
# 4   /iWUouGcOAB49ASJV45HD5JL1pxC.jpg   2024-12-26          Your Fault  False
# ..                               ...          ...                 ...    ...
# 95  /ory8WuAqznTE7lfopTSymHpop2t.jpg   2009-05-12      Heavenly Touch  False
# 96  /AjV6jFJ2YFIluYo4GQf13AA1tqu.jpg   2024-08-07     It Ends with Us  False
# 97  /AjV6jFJ2YFIluYo4GQf13AA1tqu.jpg   2024-08-07     It Ends with Us  False
# 98  /isb2Qow76GpqYmsSyfdMfsYAjts.jpg   2005-09-12        Corpse Bride  False
# 99  /isb2Qow76GpqYmsSyfdMfsYAjts.jpg   2005-09-12        Corpse Bride  False
#
#     vote_average  vote_count
# 0          6.345        2891
# 1          6.345        2891
# 2          6.345        2891
# 3          6.345        2891
# 4          0.000           0
# ..           ...         ...
# 95         6.000          19
# 96         7.178         863
# 97         7.178         863
# 98         7.572        9103
# 99         7.572        9103
#
# [100 rows x 14 columns]
