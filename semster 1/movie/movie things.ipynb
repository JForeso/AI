# %%
import pandas as pd
import seaborn as sns
import numpy as np
import requests

# %%
import requests

url = "https://api.themoviedb.org/3/movie/now_playing?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI2NTFhMmEyMTQ4ZTNjNjY5ZDRkYTVjZmFkMzExNGNhOSIsIm5iZiI6MTcyNzk3MDUyNi45NTUyMDEsInN1YiI6IjY2ZmViNmU1ZmEzZTY5ZTBlZjdjOTE1ZCIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.GTX5Uj6NFe637Sx5x1m4l07KoMil3GD0hFVCcxhTdBw"
}

response = requests.get(url, headers=headers)
response= response.json()
now= pd.DataFrame(response["results"])

now
# Out:
#     adult                     backdrop_path             genre_ids       id  \
# 0   False  /Asg2UUwipAdE87MxtJy7SQo08XI.jpg  [28, 14, 27, 53, 80]   957452
# 1   False  /wh1IhMWkW7u5c5bkzSGFylF9G8r.jpg          [28, 80, 53]  1215162
# 2   False  /7h6TqPB3ESmjuVbxCxAeB1c9OB1.jpg             [878, 27]   933260
# 3   False  /zAqBIeO71BFL7bAtP5TFzVjVamy.jpg           [10749, 18]  1079091
# 4   False  /A1dZ6faTjg0e6HYftBmEKujuXGQ.jpg          [35, 14, 27]   917496
# 5   False  /reNf6GBzOe48l9WEnFOxXgW56Vg.jpg          [18, 80, 53]   889737
# 6   False  /qN7xSoT1iQiaR2i2EpPQedbBFvo.jpg              [27, 53]  1114513
# 7   False  /4zlOPT9CrtIX05bBIkYxNZsm5zN.jpg      [16, 878, 10751]  1184918
# 8   False  /1pbV8uC6EUYOYnPqWfrQFPdAj1O.jpg          [80, 28, 53]  1147710
# 9   False  /mKOBdgaEFguADkJhfFslY7TYxIh.jpg         [28, 878, 35]   365177
# 10  False  /blqiNjJefmY10Wx6y2vgJJWljJj.jpg              [28, 53]   949484
# 11  False  /uXDwP5qPhuRyPpQ7WkLbE6t2z5W.jpg          [28, 35, 53]   877817
# 12  False  /tAwfoDyKiYa4KQdUp3DTMrEs4En.jpg  [16, 878, 12, 10751]   698687
# 13  False  /wSZbtiFIK1fkKZdSRtn2kz2Ttfd.jpg          [28, 35, 80]  1139817
# 14  False  /jfC2xCBD8a5QJNd5yY3q23E8i7U.jpg          [28, 80, 18]  1186947
# 15  False  /pysPTtYmTcQBlShcxXZwfs3Zp8H.jpg         [878, 53, 27]  1064028
# 16  False  /9SSEUrSqhljBMzRe4aBTh17rUaC.jpg         [27, 878, 28]   945961
# 17  False  /sjC29cgm4qZAnpOJQbYKCxDCcra.jpg         [27, 878, 53]  1062215
# 18  False  /gZWl93sf8AxavYpVT1Un6EF3oCj.jpg          [80, 53, 18]   475557
# 19  False  /vt37v6ouquokPYeEg3xqkzKjHRj.jpg                  [53]  1248753
#
#    original_language           original_title  \
# 0                 en                 The Crow
# 1                 en           Kill 'em All 2
# 2                 en            The Substance
# 3                 en          It Ends with Us
# 4                 en  Beetlejuice Beetlejuice
# 5                 en      Joker: Folie à Deux
# 6                 en            Speak No Evil
# 7                 en           The Wild Robot
# 8                 ko                     하이재킹
# 9                 en              Borderlands
# 10                en            Hounds of War
# 11                en                    Wolfs
# 12                en         Transformers One
# 13                ko                    무도실무관
# 14                pt    Bandida - A Número Um
# 15                en             Subservience
# 16                en           Alien: Romulus
# 17                en                   Afraid
# 18                en                    Joker
# 19                en              Amber Alert
#
#                                              overview  popularity  \
# 0   Soulmates Eric and Shelly are brutally murdere...    1403.514
# 1   Phillip and Suzanne are retired from the spy g...    1201.354
# 2   A fading celebrity decides to use a black mark...    1131.940
# 3   When a woman's first love suddenly reenters he...    1014.814
# 4   After a family tragedy, three generations of t...     861.066
# 5   While struggling with his dual identity, Arthu...     850.848
# 6   When an American family is invited to spend th...     824.074
# 7   After a shipwreck, an intelligent robot called...     818.040
# 8   Pilots Tae-in and Gyu-sik are set to fly to Gi...     795.105
# 9   Returning to her home planet, an infamous boun...     761.349
# 10  After a mission goes wrong, only one of a grou...     726.152
# 11  Hired to cover up a high-profile crime, a fixe...     590.936
# 12  The untold origin story of Optimus Prime and M...     582.958
# 13  A talented martial artist who can't walk past ...     539.213
# 14  At the age of nine, Rebeca is sold by her gran...     520.146
# 15  With his wife out sick, a struggling father br...     477.546
# 16  While scavenging the deep ends of a derelict s...     463.177
# 17  Curtis Pike and his family are selected to tes...     445.293
# 18  During the 1980s, a failed stand-up comedian i...     380.692
# 19  An ordinary rideshare becomes a high-stakes ga...     379.144
#
#                          poster_path release_date                    title  \
# 0   /58QT4cPJ2u2TqWZkterDq9q4yxQ.jpg   2024-08-21                 The Crow
# 1   /hgA5hN3NjNNSTXYOmAI6KNKOzbp.jpg   2024-09-24           Kill 'em All 2
# 2   /lqoMzCcZYEFK729d6qzt349fB4o.jpg   2024-09-07            The Substance
# 3   /cSMdFWmajaX4oUMLx7HEDI84GkP.jpg   2024-08-07          It Ends with Us
# 4   /kKgQzkUCnQmeTPkyIwHly2t6ZFI.jpg   2024-09-04  Beetlejuice Beetlejuice
# 5   /if8QiqCI7WAGImKcJCfzp6VTyKA.jpg   2024-10-01      Joker: Folie à Deux
# 6   /dA4N6uWOnEMgbxXwFX7qX7adzs8.jpg   2024-09-11            Speak No Evil
# 7   /hn4fOpFlbak5ruxkdrmdijs38Yl.jpg   2024-09-12           The Wild Robot
# 8   /68jNkFi61MQjrJEqj2up5wZ4w5R.jpg   2024-06-21              Hijack 1971
# 9   /865DntZzOdX6rLMd405R0nFkLmL.jpg   2024-08-07              Borderlands
# 10  /lRBT73EWsiQPuqK3YS3BnBW0Zwi.jpg   2024-08-29            Hounds of War
# 11  /vOX1Zng472PC2KnS0B9nRfM8aaZ.jpg   2024-09-20                    Wolfs
# 12  /qbkAqmmEIZfrCO8ZQAuIuVMlWoV.jpg   2024-09-11         Transformers One
# 13  /rEaJSXAlNfdhRpDHiNcJsoUa9qE.jpg   2024-09-10       Officer Black Belt
# 14  /rGS8SzheANVQicNba0GCE6w1XHb.jpg   2024-06-20                   Outlaw
# 15  /gBenxR01Uy0Ev9RTIw6dVBPoyQU.jpg   2024-08-15             Subservience
# 16  /b33nnKl1GSFbao4l3fZDDqsMx0F.jpg   2024-08-13           Alien: Romulus
# 17  /gUREuXCnJLVHsvKXDH9fgIcfM6e.jpg   2024-08-28                   Afraid
# 18  /udDclJoHjfjb8Ekgsd4FDteOkCU.jpg   2019-10-01                    Joker
# 19  /vkrmJ2fStfnvsLfBw55nimnjcd5.jpg   2024-09-27              Amber Alert
#
#     video  vote_average  vote_count
# 0   False         5.400         459
# 1   False         7.186          51
# 2   False         7.269         195
# 3   False         6.920         615
# 4   False         7.156         764
# 5   False         6.470          82
# 6   False         7.100         302
# 7   False         7.800          83
# 8   False         6.400          37
# 9   False         5.876         630
# 10  False         6.454          65
# 11  False         6.614         250
# 12  False         7.347          98
# 13  False         7.937         158
# 14  False         6.482          55
# 15  False         6.592         147
# 16  False         7.100        1105
# 17  False         6.427         158
# 18  False         8.200       25263
# 19  False         5.800          13

# %%
import requests

url = "https://api.themoviedb.org/3/movie/popular?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI2NTFhMmEyMTQ4ZTNjNjY5ZDRkYTVjZmFkMzExNGNhOSIsIm5iZiI6MTcyNzk3MDUyNi45NTUyMDEsInN1YiI6IjY2ZmViNmU1ZmEzZTY5ZTBlZjdjOTE1ZCIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.GTX5Uj6NFe637Sx5x1m4l07KoMil3GD0hFVCcxhTdBw"
}

response1 = requests.get(url, headers=headers)
response1= response1.json()
pop= pd.DataFrame(response1["results"])
pop
# Out:
#     adult                     backdrop_path                genre_ids       id  \
# 0   False  /dvBCdCohwWbsP5qAaglOXagDMtk.jpg            [28, 35, 878]   533535
# 1   False  /lgkPzcOSnTvjeMnuFzozRO5HHw1.jpg      [16, 10751, 35, 28]   519182
# 2   False  /Asg2UUwipAdE87MxtJy7SQo08XI.jpg     [28, 14, 27, 53, 80]   957452
# 3   False  /p5ozvmdgsmbWe0H8Xk7Rc8SCwAB.jpg  [16, 10751, 12, 35, 18]  1022789
# 4   False  /7h6TqPB3ESmjuVbxCxAeB1c9OB1.jpg                [878, 27]   933260
# 5   False  /zAqBIeO71BFL7bAtP5TFzVjVamy.jpg              [10749, 18]  1079091
# 6   False  /A1dZ6faTjg0e6HYftBmEKujuXGQ.jpg                 [35, 14]   917496
# 7   False  /wh1IhMWkW7u5c5bkzSGFylF9G8r.jpg             [28, 80, 53]  1215162
# 8   False   /NqqLef2ITlK8olXT4iFuUXFwSh.jpg               [9648, 53]   840705
# 9   False  /1pbV8uC6EUYOYnPqWfrQFPdAj1O.jpg             [80, 28, 53]  1147710
# 10  False  /reNf6GBzOe48l9WEnFOxXgW56Vg.jpg             [18, 80, 53]   889737
# 11  False  /tncbMvfV0V07UZozXdBEq4Wu9HH.jpg         [28, 80, 53, 35]   573435
# 12  False  /mKOBdgaEFguADkJhfFslY7TYxIh.jpg            [28, 878, 35]   365177
# 13  False  /4zlOPT9CrtIX05bBIkYxNZsm5zN.jpg         [16, 878, 10751]  1184918
# 14  False  /blqiNjJefmY10Wx6y2vgJJWljJj.jpg                 [28, 53]   949484
# 15  False  /tAwfoDyKiYa4KQdUp3DTMrEs4En.jpg     [16, 878, 12, 10751]   698687
# 16  False  /sIzZQdXY21sEks9lGkGuXzqdGSA.jpg                 [14, 35]     4011
# 17  False  /nk3RLLZiRAsUxZjtZoXTu77IN03.jpg              [10751, 35]  1030076
# 18  False  /qN7xSoT1iQiaR2i2EpPQedbBFvo.jpg                 [27, 53]  1114513
# 19  False  /sjC29cgm4qZAnpOJQbYKCxDCcra.jpg            [27, 878, 53]  1062215
#
#    original_language                                original_title  \
# 0                 en                          Deadpool & Wolverine
# 1                 en                               Despicable Me 4
# 2                 en                                      The Crow
# 3                 en                                  Inside Out 2
# 4                 en                                 The Substance
# 5                 en                               It Ends with Us
# 6                 en                       Beetlejuice Beetlejuice
# 7                 en                                Kill 'em All 2
# 8                 en                                   Blink Twice
# 9                 ko                                          하이재킹
# 10                en                           Joker: Folie à Deux
# 11                en                         Bad Boys: Ride or Die
# 12                en                                   Borderlands
# 13                en                                The Wild Robot
# 14                en                                 Hounds of War
# 15                en                              Transformers One
# 16                en                                   Beetlejuice
# 17                es  Padre no hay más que uno 4: Campanas de boda
# 18                en                                 Speak No Evil
# 19                en                                        Afraid
#
#                                              overview  popularity  \
# 0   A listless Wade Wilson toils away in civilian ...    6163.133
# 1   Gru and Lucy and their girls—Margo, Edith and ...    2244.623
# 2   Soulmates Eric and Shelly are brutally murdere...    1403.514
# 3   Teenager Riley's mind headquarters is undergoi...    1220.104
# 4   A fading celebrity decides to use a black mark...    1131.940
# 5   When a woman's first love suddenly reenters he...    1014.814
# 6   After a family tragedy, three generations of t...     861.066
# 7   Phillip and Suzanne are retired from the spy g...    1201.354
# 8   When tech billionaire Slater King meets cockta...     858.690
# 9   Pilots Tae-in and Gyu-sik are set to fly to Gi...     795.105
# 10  While struggling with his dual identity, Arthu...     850.848
# 11  After their late former Captain is framed, Low...     799.533
# 12  Returning to her home planet, an infamous boun...     761.349
# 13  After a shipwreck, an intelligent robot called...     818.040
# 14  After a mission goes wrong, only one of a grou...     726.152
# 15  The untold origin story of Optimus Prime and M...     582.958
# 16  A newly dead New England couple seeks help fro...     516.369
# 17  The eldest of the family, Sara, comes of age a...     595.838
# 18  When an American family is invited to spend th...     824.074
# 19  Curtis Pike and his family are selected to tes...     445.293
#
#                          poster_path release_date  \
# 0   /8cdWjvZQUExUUTzyp4t6EDMubfO.jpg   2024-07-24
# 1   /wWba3TaojhK7NdycRhoQpsG0FaH.jpg   2024-06-20
# 2   /58QT4cPJ2u2TqWZkterDq9q4yxQ.jpg   2024-08-21
# 3   /vpnVM9B6NMmQpWeZvzLvDESb2QY.jpg   2024-06-11
# 4   /lqoMzCcZYEFK729d6qzt349fB4o.jpg   2024-09-07
# 5   /cSMdFWmajaX4oUMLx7HEDI84GkP.jpg   2024-08-07
# 6   /kKgQzkUCnQmeTPkyIwHly2t6ZFI.jpg   2024-09-04
# 7   /hgA5hN3NjNNSTXYOmAI6KNKOzbp.jpg   2024-09-24
# 8   /lZGOK0I2DJSRlEPNOAFTSNxSjDD.jpg   2024-08-21
# 9   /68jNkFi61MQjrJEqj2up5wZ4w5R.jpg   2024-06-21
# 10  /if8QiqCI7WAGImKcJCfzp6VTyKA.jpg   2024-10-01
# 11  /oGythE98MYleE6mZlGs5oBGkux1.jpg   2024-06-05
# 12  /865DntZzOdX6rLMd405R0nFkLmL.jpg   2024-08-07
# 13  /hn4fOpFlbak5ruxkdrmdijs38Yl.jpg   2024-09-12
# 14  /lRBT73EWsiQPuqK3YS3BnBW0Zwi.jpg   2024-08-29
# 15  /qbkAqmmEIZfrCO8ZQAuIuVMlWoV.jpg   2024-09-11
# 16  /nnl6OWkyPpuMm595hmAxNW3rZFn.jpg   1988-03-30
# 17   /hTMvGolGJLF0GQ7mlwNjbXpsPZ.jpg   2024-07-17
# 18  /dA4N6uWOnEMgbxXwFX7qX7adzs8.jpg   2024-09-11
# 19  /gUREuXCnJLVHsvKXDH9fgIcfM6e.jpg   2024-08-28
#
#                                            title  video  vote_average  \
# 0                           Deadpool & Wolverine  False         7.800
# 1                                Despicable Me 4  False         7.200
# 2                                       The Crow  False         5.402
# 3                                   Inside Out 2  False         7.600
# 4                                  The Substance  False         7.269
# 5                                It Ends with Us  False         6.922
# 6                        Beetlejuice Beetlejuice  False         7.155
# 7                                 Kill 'em All 2  False         7.130
# 8                                    Blink Twice  False         6.679
# 9                                    Hijack 1971  False         6.400
# 10                           Joker: Folie à Deux  False         6.500
# 11                         Bad Boys: Ride or Die  False         7.549
# 12                                   Borderlands  False         5.876
# 13                                The Wild Robot  False         7.800
# 14                                 Hounds of War  False         6.454
# 15                              Transformers One  False         7.347
# 16                                   Beetlejuice  False         7.374
# 17  Padre no hay más que uno 4: Campanas de boda  False         6.500
# 18                                 Speak No Evil  False         7.100
# 19                                        Afraid  False         6.436
#
#     vote_count
# 0         3605
# 1         1824
# 2          459
# 3         4032
# 4          195
# 5          614
# 6          763
# 7           50
# 8          506
# 9           37
# 10          78
# 11        2080
# 12         630
# 13          83
# 14          65
# 15          98
# 16        7178
# 17          18
# 18         300
# 19         157

# %%
import requests

url = "https://api.themoviedb.org/3/movie/top_rated?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI2NTFhMmEyMTQ4ZTNjNjY5ZDRkYTVjZmFkMzExNGNhOSIsIm5iZiI6MTcyNzk3MDUyNi45NTUyMDEsInN1YiI6IjY2ZmViNmU1ZmEzZTY5ZTBlZjdjOTE1ZCIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.GTX5Uj6NFe637Sx5x1m4l07KoMil3GD0hFVCcxhTdBw"
}

response2 = requests.get(url, headers=headers)
response2= response2.json()
top= pd.DataFrame(response2["results"])
top
# Out:
#     adult                     backdrop_path                    genre_ids  \
# 0   False  /kXfqcdQKsToO0OUXHcrrNCHDBzO.jpg                     [18, 80]
# 1   False  /tmU7GeKVybMWFButWEGl2M4GeiP.jpg                     [18, 80]
# 2   False  /kGzFbGhp99zva6oZODW5atUtnqi.jpg                     [18, 80]
# 3   False  /zb6fM1CX41D9rF9hdgclu0peUmy.jpg              [18, 36, 10752]
# 4   False  /qqHQsStV6exghCM7zbObuYBiYxw.jpg                         [18]
# 5   False  /6oaL4DP75yABrd5EbC4H2zq5ghc.jpg              [16, 10751, 14]
# 6   False  /90ez6ArvpO8bvpyIngBuwXOqJm5.jpg              [35, 18, 10749]
# 7   False  /nMKdUUepR0i5zn0y1T4CsSB5chy.jpg             [18, 28, 80, 53]
# 8   False  /8eihUxjQsJ7WvGySkVMC0EwbPAD.jpg                 [35, 53, 18]
# 9   False  /vxJ08SvwomfKbpboCWynC3uqUg4.jpg                 [14, 18, 80]
# 10  False  /suaEOtk1N1sgg2MTM7oZd2cfVp3.jpg                     [53, 80]
# 11  False  /dIWwZW7dJJtqC6CgWzYkNVKIUm8.jpg              [16, 10749, 18]
# 12  False  /2u7zbn8EudG6kLlBzUYqP8RyFU4.jpg                 [12, 14, 28]
# 13  False  /ghgfzbEV7kbpbi1O8eIILKVXEA8.jpg              [35, 18, 10749]
# 14  False  /Adrip2Jqzw56KeuV2nAxucKMNXA.jpg                         [37]
# 15  False  /7TF4p86ZafnxFuNqWdhpHXFO244.jpg                     [18, 80]
# 16  False  /sJNNMCc6B7KZIY3LH3JMYJJNH5j.jpg                     [28, 18]
# 17  False  /gwj4R8Uy1GwejKqfofREKI9Jh7L.jpg              [16, 18, 10752]
# 18  False  /i9qxG4UVgfX4AdMGnfRzMYEowLQ.jpg  [12, 36, 28, 18, 10749, 53]
# 19  False  /7lyq8hK0MhPHpUXdnqbFvZYSfkk.jpg                  [18, 10749]
#
#          id original_language                                 original_title  \
# 0       278                en                       The Shawshank Redemption
# 1       238                en                                  The Godfather
# 2       240                en                          The Godfather Part II
# 3       424                en                               Schindler's List
# 4       389                en                                   12 Angry Men
# 5       129                ja                                       千と千尋の神隠し
# 6     19404                hi                   दिलवाले दुल्हनिया ले जायेंगे
# 7       155                en                                The Dark Knight
# 8    496243                ko                                            기생충
# 9       497                en                                 The Green Mile
# 10      680                en                                   Pulp Fiction
# 11   372058                ja                                          君の名は。
# 12      122                en  The Lord of the Rings: The Return of the King
# 13       13                en                                   Forrest Gump
# 14      429                it                Il buono, il brutto, il cattivo
# 15      769                en                                     GoodFellas
# 16      346                ja                                           七人の侍
# 17    12477                ja                                          火垂るの墓
# 18  1084736                fr                       Le Comte de Monte-Cristo
# 19    11216                it                          Nuovo Cinema Paradiso
#
#                                              overview  popularity  \
# 0   Imprisoned in the 1940s for the double murder ...     136.210
# 1   Spanning the years 1945 to 1955, a chronicle o...     106.566
# 2   In the continuing saga of the Corleone crime f...      88.012
# 3   The true story of how businessman Oskar Schind...      71.445
# 4   The defense and the prosecution have rested an...      42.328
# 5   A young girl, Chihiro, becomes trapped in a st...      87.334
# 6   Raj is a rich, carefree, happy-go-lucky second...      38.466
# 7   Batman raises the stakes in his war on crime. ...     136.868
# 8   All unemployed, Ki-taek's family takes peculia...      71.086
# 9   A supernatural tale set on death row in a Sout...      72.532
# 10  A burger-loving hit man, his philosophical par...      73.605
# 11  High schoolers Mitsuha and Taki are complete s...      75.914
# 12  As armies mass for a final battle that will de...     177.281
# 13  A man with a low IQ has accomplished great thi...      79.106
# 14  While the Civil War rages on between the Union...      93.599
# 15  The true story of Henry Hill, a half-Irish, ha...      54.317
# 16  A samurai answers a village's request for prot...      35.363
# 17  In the final months of World War II, 14-year-o...       0.066
# 18  Edmond Dantes becomes the target of a sinister...      72.414
# 19  A filmmaker recalls his childhood, when he fel...      26.434
#
#                          poster_path release_date  \
# 0   /9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg   1994-09-23
# 1   /3bhkrj58Vtu7enYsRolD1fZdja1.jpg   1972-03-14
# 2   /hek3koDUyRQk7FIhPXsa6mT2Zc3.jpg   1974-12-20
# 3   /sF1U4EUQS8YHUYjNl3pMGNIQyr0.jpg   1993-12-15
# 4   /ow3wq89wM8qd5X7hWKxiRfsFf9C.jpg   1957-04-10
# 5   /39wmItIWsg5sZMyRUHLkWBcuVCM.jpg   2001-07-20
# 6   /lfRkUr7DYdHldAqi3PwdQGBRBPM.jpg   1995-10-20
# 7   /qJ2tW6WMUDux911r6m7haRef0WH.jpg   2008-07-16
# 8   /7IiTTgloJzvGI1TAYymCfbfl3vT.jpg   2019-05-30
# 9   /8VG8fDNiy50H4FedGwdSVUPoaJe.jpg   1999-12-10
# 10  /d5iIlFn5s0ImszYzBPb8JPIfbXD.jpg   1994-09-10
# 11  /vfJFJPepRKapMd5G2ro7klIRysq.jpg   2016-08-26
# 12  /rCzpDGLbOoPwLjy3OAm5NUPOTrC.jpg   2003-12-17
# 13  /arw2vcBveWOVZr6pxd9XTd1TdQa.jpg   1994-06-23
# 14  /bX2xnavhMYjWDoZp1VM6VnU1xwe.jpg   1966-12-22
# 15  /aKuFiU82s5ISJpGZp7YkIr3kCUd.jpg   1990-09-12
# 16  /8OKmBV5BUFzmozIC3pPWKHy17kx.jpg   1954-04-26
# 17  /k9tv1rXZbOhH7eiCk378x61kNQ1.jpg   1988-04-16
# 18  /4wrBcjtAXNNYfK7OChRqCnExCsu.jpg   2024-06-28
# 19  /gCI2AeMV4IHSewhJkzsur5MEp6R.jpg   1988-11-17
#
#                                             title  video  vote_average  \
# 0                        The Shawshank Redemption  False         8.706
# 1                                   The Godfather  False         8.690
# 2                           The Godfather Part II  False         8.575
# 3                                Schindler's List  False         8.564
# 4                                    12 Angry Men  False         8.500
# 5                                   Spirited Away  False         8.537
# 6                     Dilwale Dulhania Le Jayenge  False         8.529
# 7                                 The Dark Knight  False         8.516
# 8                                        Parasite  False         8.507
# 9                                  The Green Mile  False         8.507
# 10                                   Pulp Fiction  False         8.488
# 11                                     Your Name.  False         8.487
# 12  The Lord of the Rings: The Return of the King  False         8.500
# 13                                   Forrest Gump  False         8.473
# 14                 The Good, the Bad and the Ugly  False         8.461
# 15                                     GoodFellas  False         8.461
# 16                                  Seven Samurai  False         8.461
# 17                         Grave of the Fireflies  False         8.457
# 18                      The Count of Monte-Cristo  False         8.452
# 19                                Cinema Paradiso  False         8.449
#
#     vote_count
# 0        26880
# 1        20397
# 2        12309
# 3        15717
# 4         8539
# 5        16362
# 6         4428
# 7        32627
# 8        18072
# 9        17258
# 10       27698
# 11       11275
# 12       23984
# 13       27212
# 14        8521
# 15       12746
# 16        3622
# 17        5453
# 18         577
# 19        4323

# %%
import requests

url = "https://api.themoviedb.org/3/movie/upcoming?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI2NTFhMmEyMTQ4ZTNjNjY5ZDRkYTVjZmFkMzExNGNhOSIsIm5iZiI6MTcyNzk3MDUyNi45NTUyMDEsInN1YiI6IjY2ZmViNmU1ZmEzZTY5ZTBlZjdjOTE1ZCIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.GTX5Uj6NFe637Sx5x1m4l07KoMil3GD0hFVCcxhTdBw"
}

response3 = requests.get(url, headers=headers)
response3= response3.json()
up= pd.DataFrame(response3["results"])
up
# Out:
#     adult                     backdrop_path                genre_ids       id  \
# 0   False  /7h6TqPB3ESmjuVbxCxAeB1c9OB1.jpg                [878, 27]   933260
# 1   False  /reNf6GBzOe48l9WEnFOxXgW56Vg.jpg             [18, 80, 53]   889737
# 2   False  /4zlOPT9CrtIX05bBIkYxNZsm5zN.jpg         [16, 878, 10751]  1184918
# 3   False  /tAwfoDyKiYa4KQdUp3DTMrEs4En.jpg     [16, 878, 12, 10751]   698687
# 4   False  /sjC29cgm4qZAnpOJQbYKCxDCcra.jpg            [27, 878, 53]  1062215
# 5   False  /hdFIdXwS8FSN2wIsuotjW1mshI0.jpg      [16, 35, 12, 10751]   831815
# 6   False   /FzntbxhtPGp5gVmie16ry3k7Ow.jpg      [16, 35, 10751, 14]   567811
# 7   False  /bizhlTVjifYQUu4Xrdt7m3TYr7d.jpg             [80, 27, 53]  1226578
# 8   False  /9juRmk8QjcsUcbrevVu5t8VZy5G.jpg         [28, 12, 80, 53]   923667
# 9   False  /tCQfubckzzcuCbsGugkpLhfjS5z.jpg             [28, 53, 80]   970347
# 10  False  /3V4kLQg0kSqPLctI5ziYWabAZYF.jpg            [28, 878, 12]   912649
# 11  False  /h9YlRHAZWOWtGonllmj6JJg1FrE.jpg  [28, 12, 16, 10751, 14]   588648
# 12  False  /t3LicFpYHeYpwqm7L5wDpd22hL5.jpg                 [12, 14]      671
# 13  False  /p5kpFS0P3lIwzwzHBOULQovNWyj.jpg             [53, 80, 27]  1032823
# 14  False  /yHzyPJrVqlTySQ9mc379yxrLBYQ.jpg                 [12, 14]      672
# 15  False  /vJk9DOLgP23jO5mBnPHE93MFgYu.jpg      [12, 10751, 14, 35]   826510
# 16  False  /obKmfNexgL4ZP5cAmzdL4KbHHYX.jpg                 [12, 14]      673
# 17  False  /AfXoko90cVuDz1KuVamkSMRKBWy.jpg                 [35, 18]  1125073
# 18  False  /xlkclSE4aq7r3JsFIJRgs21zUew.jpg                 [27, 53]  1034541
# 19  False  /b6DU3kBmicMbpNvvkqf1cHaceMF.jpg                 [27, 18]   814889
#
#    original_language                                original_title  \
# 0                 en                                 The Substance
# 1                 en                           Joker: Folie à Deux
# 2                 en                                The Wild Robot
# 3                 en                              Transformers One
# 4                 en                                        Afraid
# 5                 en  Saving Bikini Bottom: The Sandy Cheeks Movie
# 6                 en                                      10 Lives
# 7                 en                                      Longlegs
# 8                 cn                                       九龍城寨之圍城
# 9                 en                                    The Killer
# 10                en                         Venom: The Last Dance
# 11                zh                                  Dragonkeeper
# 12                en      Harry Potter and the Philosopher's Stone
# 13                en                                          Trap
# 14                en       Harry Potter and the Chamber of Secrets
# 15                en                  Harold and the Purple Crayon
# 16                en      Harry Potter and the Prisoner of Azkaban
# 17                en                           Between the Temples
# 18                en                                   Terrifier 3
# 19                en                                  Never Let Go
#
#                                              overview  popularity  \
# 0   A fading celebrity decides to use a black mark...    1131.940
# 1   While struggling with his dual identity, Arthu...     850.848
# 2   After a shipwreck, an intelligent robot called...     818.040
# 3   The untold origin story of Optimus Prime and M...     582.958
# 4   Curtis Pike and his family are selected to tes...     445.293
# 5   When Bikini Bottom is scooped from the ocean, ...     363.108
# 6   A pampered cat takes for granted the lucky han...     321.917
# 7   FBI Agent Lee Harker is assigned to an unsolve...     295.610
# 8   In 1980s Hong Kong, troubled youth Chan Lok-kw...     311.878
# 9   Zee is a feared contract killer known as "the ...     263.953
# 10  Eddie and Venom are on the run. Hunted by both...     271.337
# 11  Set in Han Imperial China, the plot follows th...     244.425
# 12  Harry Potter has lived under the stairs at his...     199.058
# 13  A father and teen daughter attend a pop concer...     209.015
# 14  Cars fly, trees fight back, and a mysterious h...     177.754
# 15  Inside of his book, adventurous Harold can mak...     193.794
# 16  Year three at Hogwarts means new fun and chall...     162.345
# 17  A grief-stricken cantor in a crisis of faith f...     147.951
# 18  After surviving Art the Clown's Halloween mass...     136.818
# 19  As an evil takes over the world beyond their f...     113.360
#
#                          poster_path release_date  \
# 0   /lqoMzCcZYEFK729d6qzt349fB4o.jpg   2024-09-07
# 1   /if8QiqCI7WAGImKcJCfzp6VTyKA.jpg   2024-10-01
# 2   /hn4fOpFlbak5ruxkdrmdijs38Yl.jpg   2024-09-12
# 3   /qbkAqmmEIZfrCO8ZQAuIuVMlWoV.jpg   2024-09-11
# 4   /gUREuXCnJLVHsvKXDH9fgIcfM6e.jpg   2024-08-28
# 5   /30YnfZdMNIV7noWLdvmcJS0cbnQ.jpg   2024-10-18
# 6   /r2D7MkNocsqKOqGnnGEQThU26JS.jpg   2024-04-18
# 7   /5aj8vVGFwGVbQQs26ywhg4Zxk2L.jpg   2024-05-31
# 8    /PywbVPeIhBFc33QXktnhMaysmL.jpg   2024-04-23
# 9   /6PCnxKZZIVRanWb710pNpYVkCSw.jpg   2024-08-22
# 10  /aosm8NMQ3UyoBVpSxyimorCQykC.jpg   2024-10-23
# 11  /ggZGnJLzO3BTu7ysuuIzou3Oex5.jpg   2024-04-11
# 12  /wuMc08IPKEatf9rnMNXvIDxqP4W.jpg   2001-11-16
# 13  /jwoaKYVqPgYemFpaANL941EF94R.jpg   2024-07-31
# 14  /sdEOH0992YZ0QSxgXNIGLq1ToUi.jpg   2002-11-13
# 15  /dEsuQOZwdaFAVL26RjgjwGl9j7m.jpg   2024-07-31
# 16  /aWxwnYoe8p2d2fcxOqtvAtJ72Rw.jpg   2004-05-31
# 17  /iOVe3xoJDIdMMYvCy18a4TlDIOK.jpg   2024-08-22
# 18  /fD4ZNG3r6qWH4DBXw2CHonm2yHK.jpg   2024-10-09
# 19  /3EpZ2ksjijmdr8BhISP03PYzNFW.jpg   2024-09-18
#
#                                            title  video  vote_average  \
# 0                                  The Substance  False         7.269
# 1                            Joker: Folie à Deux  False         6.481
# 2                                 The Wild Robot  False         7.800
# 3                               Transformers One  False         7.347
# 4                                         Afraid  False         6.427
# 5   Saving Bikini Bottom: The Sandy Cheeks Movie  False         0.000
# 6                                       10 Lives  False         8.400
# 7                                       Longlegs  False         6.677
# 8            Twilight of the Warriors: Walled In  False         6.585
# 9                                     The Killer  False         6.647
# 10                         Venom: The Last Dance  False         0.000
# 11                                  Dragonkeeper  False         7.200
# 12      Harry Potter and the Philosopher's Stone  False         7.913
# 13                                          Trap  False         6.513
# 14       Harry Potter and the Chamber of Secrets  False         7.720
# 15                  Harold and the Purple Crayon  False         7.100
# 16      Harry Potter and the Prisoner of Azkaban  False         8.019
# 17                           Between the Temples  False         5.100
# 18                                   Terrifier 3  False         0.000
# 19                                  Never Let Go  False         5.910
#
#     vote_count
# 0          195
# 1           80
# 2           83
# 3           98
# 4          158
# 5            0
# 6           89
# 7          960
# 8          171
# 9          245
# 10           0
# 11         109
# 12       27136
# 13        1239
# 14       21720
# 15         144
# 16       21342
# 17           7
# 18           0
# 19          39
