# %%
import pandas as pd
import seaborn as sns
import numpy as np
import requests
import math

# %%
import requests

url = "https://api.themoviedb.org/3/movie/now_playing?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI2NTFhMmEyMTQ4ZTNjNjY5ZDRkYTVjZmFkMzExNGNhOSIsIm5iZiI6MTcyNzk3MDUyNi45NTUyMDEsInN1YiI6IjY2ZmViNmU1ZmEzZTY5ZTBlZjdjOTE1ZCIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.GTX5Uj6NFe637Sx5x1m4l07KoMil3GD0hFVCcxhTdBw"
}

response = requests.get(url, headers=headers)
response= response.json()
now= pd.DataFrame(response["results"])

# %%
import requests

url = "https://api.themoviedb.org/3/movie/popular?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI2NTFhMmEyMTQ4ZTNjNjY5ZDRkYTVjZmFkMzExNGNhOSIsIm5iZiI6MTcyNzk3MDUyNi45NTUyMDEsInN1YiI6IjY2ZmViNmU1ZmEzZTY5ZTBlZjdjOTE1ZCIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.GTX5Uj6NFe637Sx5x1m4l07KoMil3GD0hFVCcxhTdBw"
}

response1 = requests.get(url, headers=headers)
response1= response1.json()
pop= pd.DataFrame(response1["results"])

# %%
import requests

url = "https://api.themoviedb.org/3/movie/top_rated?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI2NTFhMmEyMTQ4ZTNjNjY5ZDRkYTVjZmFkMzExNGNhOSIsIm5iZiI6MTcyNzk3MDUyNi45NTUyMDEsInN1YiI6IjY2ZmViNmU1ZmEzZTY5ZTBlZjdjOTE1ZCIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.GTX5Uj6NFe637Sx5x1m4l07KoMil3GD0hFVCcxhTdBw"
}

response2 = requests.get(url, headers=headers)
response2= response2.json()
top= pd.DataFrame(response2["results"])

# %%
import requests

url = "https://api.themoviedb.org/3/movie/upcoming?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI2NTFhMmEyMTQ4ZTNjNjY5ZDRkYTVjZmFkMzExNGNhOSIsIm5iZiI6MTcyNzk3MDUyNi45NTUyMDEsInN1YiI6IjY2ZmViNmU1ZmEzZTY5ZTBlZjdjOTE1ZCIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.GTX5Uj6NFe637Sx5x1m4l07KoMil3GD0hFVCcxhTdBw"
}

response3 = requests.get(url, headers=headers)
response3= response3.json()
up= pd.DataFrame(response3["results"])

# %%
top
# Out:
#     adult                     backdrop_path         genre_ids       id  \
# 0   False  /zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg          [18, 80]      278
# 1   False  /tmU7GeKVybMWFButWEGl2M4GeiP.jpg          [18, 80]      238
# 2   False  /417tYZ4XUyJrtyZXj7HpvWf1E8f.jpg  [16, 878, 10751]  1184918
# 3   False  /kGzFbGhp99zva6oZODW5atUtnqi.jpg          [18, 80]      240
# 4   False  /zb6fM1CX41D9rF9hdgclu0peUmy.jpg   [18, 36, 10752]      424
# 5   False  /qqHQsStV6exghCM7zbObuYBiYxw.jpg              [18]      389
# 6   False  /6oaL4DP75yABrd5EbC4H2zq5ghc.jpg   [16, 10751, 14]      129
# 7   False  /90ez6ArvpO8bvpyIngBuwXOqJm5.jpg   [35, 18, 10749]    19404
# 8   False  /nMKdUUepR0i5zn0y1T4CsSB5chy.jpg  [18, 28, 80, 53]      155
# 9   False  /8eihUxjQsJ7WvGySkVMC0EwbPAD.jpg      [35, 53, 18]   496243
# 10  False  /vxJ08SvwomfKbpboCWynC3uqUg4.jpg      [14, 18, 80]      497
# 11  False  /suaEOtk1N1sgg2MTM7oZd2cfVp3.jpg          [53, 80]      680
# ...

# %%
df= pd.concat([now,up,pop,top])

# %%
df
# Out:
#     adult                     backdrop_path         genre_ids       id  \
# 0   False  /417tYZ4XUyJrtyZXj7HpvWf1E8f.jpg  [16, 878, 10751]  1184918
# 1   False  /7h6TqPB3ESmjuVbxCxAeB1c9OB1.jpg     [27, 18, 878]   933260
# 2   False  /4KHEK6AQFHhv4TDtL3KLReePB05.jpg      [28, 27, 53]  1029235
# 3   False  /eQEgKIRF7KeVGBQ8IYcklpU8RPf.jpg          [27, 53]  1034541
# 4   False  /3V4kLQg0kSqPLctI5ziYWabAZYF.jpg     [28, 878, 12]   912649
# ..    ...                               ...               ...      ...
# 15  False  /Adrip2Jqzw56KeuV2nAxucKMNXA.jpg              [37]      429
# 16  False  /7TF4p86ZafnxFuNqWdhpHXFO244.jpg          [18, 80]      769
# 17  False  /sJNNMCc6B7KZIY3LH3JMYJJNH5j.jpg          [28, 18]      346
# 18  False  /gwj4R8Uy1GwejKqfofREKI9Jh7L.jpg   [16, 18, 10752]    12477
# 19  False  /7lyq8hK0MhPHpUXdnqbFvZYSfkk.jpg       [18, 10749]    11216
#
#    original_language                   original_title  \
# 0                 en                   The Wild Robot
# ...

# %%
df.drop_duplicates(subset=['original_title'], inplace=True)

# %%
def get_revenue_budget(df):
    '''
    Uses the movie id to get data from the "Details" endpoint
    returns a dataframe of revenue and budget data
    '''
    data = {
        "id":[],
        "budget": [],
        "revenue": []
    }

    for i in df["id"]:
        data["id"].append(i)
        url = "https://api.themoviedb.org/3/movie/"+str(i)+"?language=en-US"

        headers = {
            "accept": "application/json",
            "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI4Nzk4M2ZiZTk3Njk4OGE5ZTIyMzMwZWJmMDMwYTFhZSIsIm5iZiI6MTcyNzk3MTk0OS45MTA1MjcsInN1YiI6IjYzNzQyNGMyNDZlNzVmMDA5MGE3YmRhYyIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.ZsTpMVaVlF8ioN3-WiYEatqWmnGQhCKlILQv4Xi6Eec"
        }

        response = requests.get(url, headers=headers)
        response = response.json()
        data["budget"].append(response["budget"])
        data["revenue"].append(response["revenue"])
        
    return pd.DataFrame(data)

# %%
mdf = get_revenue_budget(df)

# %%
df = pd.merge(df, mdf, how="inner", on="id")

# %%
df
# Out:
#     adult                     backdrop_path                    genre_ids  \
# 0   False  /417tYZ4XUyJrtyZXj7HpvWf1E8f.jpg             [16, 878, 10751]
# 1   False  /7h6TqPB3ESmjuVbxCxAeB1c9OB1.jpg                [27, 18, 878]
# 2   False  /4KHEK6AQFHhv4TDtL3KLReePB05.jpg                 [28, 27, 53]
# 3   False  /eQEgKIRF7KeVGBQ8IYcklpU8RPf.jpg                     [27, 53]
# 4   False  /3V4kLQg0kSqPLctI5ziYWabAZYF.jpg                [28, 878, 12]
# 5   False  /xi1VSt3DtkevUmzCx2mNlCoDe74.jpg                 [35, 14, 27]
# 6   False  /g1z1ZvYKcmk9EnVOTYXR6vkNjkZ.jpg                 [14, 27, 28]
# 7   False  /3m0j3hCS8kMAaP9El6Vy5Lqnyft.jpg            [878, 53, 27, 18]
# 8   False  /64tinBsds1nVp4wOCgYhMbSgsRW.jpg                 [28, 18, 36]
# 9   False  /of1tQasFGCeHgWPmSgdA1WS6hNW.jpg                 [80, 53, 28]
# 10  False  /reNf6GBzOe48l9WEnFOxXgW56Vg.jpg                 [18, 80, 53]
# 11  False   /l8OyAXEp5FKZWmDhqJMbiwAEvz.jpg                     [27, 18]
# ...

# %%
sns.regplot(data=df, x="budget", y="revenue")
# Out:
# <AxesSubplot:xlabel='budget', ylabel='revenue'>

# %%
def bfl(data, x, y):

    m = 0
    
    for count in range(100):
        m = m + 1
        b = 0
        res = 0
        mp=0
        bp=0
        rp=0
        for i in range(len(data)):
        
            pred_y = (m * data.loc[i][x]) + b
            act_y = data.loc[i][y]
            temp = act_y - pred_y 
            temp = temp ** 2
            res = res + temp
            
            
            if res <= rp and res!=0:
                mp=m
                bp=b
                rp=res
            
            
           
            
        
    return (mp, bp, rp)

# %%
bfl(df,'budget','revenue')
# Out:
# C:\Users\jforesoii\AppData\Local\Temp\ipykernel_6448\1647860326.py:18: RuntimeWarning: overflow encountered in longlong_scalars
#   res = res + temp
# (100, 0, -8490215942243330999)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 57 entries, 0 to 56
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   adult              57 non-null     bool
#  1   backdrop_path      57 non-null     object
#  2   genre_ids          57 non-null     object
#  3   id                 57 non-null     int64
#  4   original_language  57 non-null     object
#  5   original_title     57 non-null     object
#  6   overview           57 non-null     object
#  7   popularity         57 non-null     float64
#  8   poster_path        57 non-null     object
#  9   release_date       57 non-null     object
#  10  title              57 non-null     object
#  11  video              57 non-null     bool
#  12  vote_average       57 non-null     float64
#  13  vote_count         57 non-null     int64
#  14  budget             57 non-null     int64
#  15  revenue            57 non-null     int64
# ...

# %%
def get_r2(df, x, y, m, b):
    mean = df[y].mean()
    total_sst = 0
    # Calculate SST
    for value in df[y]:
        difference = (value - mean)
        squared = difference ** 2
        total_sst += squared
    
    total_ssr = 0
    # Calculate SSR
    for i in range(len(df)):
        predicted = (m * df.loc[i][x]) + b
        difference = predicted - df.loc[i][y]
        squared = difference ** 2
        total_ssr += squared
    
    r2 = 1 - (total_ssr / total_sst)
    return r2

# %%
url = "https://api.themoviedb.org/3/movie/popular?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI2NTFhMmEyMTQ4ZTNjNjY5ZDRkYTVjZmFkMzExNGNhOSIsIm5iZiI6MTcyOTY5NjgzMS44NjgzODIsInN1YiI6IjY2ZmViNmU1ZmEzZTY5ZTBlZjdjOTE1ZCIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.aSNfKHlCxM5qldMxSqsA5kcpYOV2WKW5H8oDC5KEe_I"
}



response3 = requests.get(url, headers=headers)
response3= response3.json()
act= pd.DataFrame(response3["results"])
rom= pd.DataFrame(response3["results"])

# %%
page=2


while len(act)< 100 and len(rom)< 100:
    url = "https://api.themoviedb.org/3/movie/popular?language=en-US&page="+str(page)


    headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI2NTFhMmEyMTQ4ZTNjNjY5ZDRkYTVjZmFkMzExNGNhOSIsIm5iZiI6MTcyOTY5NjgzMS44NjgzODIsInN1YiI6IjY2ZmViNmU1ZmEzZTY5ZTBlZjdjOTE1ZCIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.aSNfKHlCxM5qldMxSqsA5kcpYOV2WKW5H8oDC5KEe_I"
}



    
    page+=1

    
    response = requests.get(url, headers=headers)
    
    response = response.json()["results"]

   

    
    for i in range(len(response)):
        
       gen=response[i]['genre_ids']
       
        temp= pd.DataFrame(response[i])
        
        if 28 in gen:
            
            act=pd.concat([act,temp ], ignore_index=True)
        
        if 10749 in gen:
           
        rom=pd.concat([rom,temp ], ignore_index=True)


    #10749
# Out:
#   File "C:\Users\jforesoii\AppData\Local\Temp\ipykernel_6448\2894427996.py", line 30
#     temp= pd.DataFrame(response[i])
#     ^
# IndentationError: unexpected indent

# %%
act
# Out:
#     adult                     backdrop_path            genre_ids       id  \
# 0   False  /417tYZ4XUyJrtyZXj7HpvWf1E8f.jpg     [16, 878, 10751]  1184918
# 1   False  /9SSEUrSqhljBMzRe4aBTh17rUaC.jpg            [878, 27]   945961
# 2   False  /7h6TqPB3ESmjuVbxCxAeB1c9OB1.jpg        [27, 18, 878]   933260
# 3   False  /yDHYTfA3R0jFYba16jBB1ef8oIt.jpg        [28, 35, 878]   533535
# 4   False  /4KHEK6AQFHhv4TDtL3KLReePB05.jpg         [28, 27, 53]  1029235
# ..    ...                               ...                  ...      ...
# 95  False  /4XM8DUTQb3lhLemJC51Jx4a2EuA.jpg         [28, 80, 53]   385687
# 96  False  /pB4FUn08MqRgjxIIUVElljpmnt8.jpg      [16, 10751, 14]    14836
# 97  False  /vHJlbhsXrZ5yrO2KqCbGSIU6fRX.jpg  [28, 9648, 878, 53]   198663
# 98  False   /NqqLef2ITlK8olXT4iFuUXFwSh.jpg       [9648, 53, 27]   840705
# 99  False  /2vFuG6bWGyQUzYS9d69E5l85nIz.jpg        [878, 12, 28]   667538
#
#    original_language                    original_title  \
# ...

# %%
def gene(df):
    '''
    Uses the movie id to get data from the "Details" endpoint
    returns a dataframe of revenue and budget data
    '''
    data = {
        "id":[],
        "genre": [],
        
    }

    for i in pop["id"]:
        data["id"].append(i)
        url = "https://api.themoviedb.org/3/movie/"+str(i)+"?language=en-US"

        headers = {
            "accept": "application/json",
            "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI4Nzk4M2ZiZTk3Njk4OGE5ZTIyMzMwZWJmMDMwYTFhZSIsIm5iZiI6MTcyNzk3MTk0OS45MTA1MjcsInN1YiI6IjYzNzQyNGMyNDZlNzVmMDA5MGE3YmRhYyIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.ZsTpMVaVlF8ioN3-WiYEatqWmnGQhCKlILQv4Xi6Eec"
        }

        response = requests.get(url, headers=headers)
        response = response.json()
        data["genre"].append(response["genres"])
        
        
    return pd.DataFrame(data)

# %%
gen= gene(df)

# %%
df = pd.merge(pop, gen, how="inner", on="id")

# %%
df
# Out:
#     adult                     backdrop_path                genre_ids       id  \
# 0   False  /kXPCUNo7ALN0S03AbmTY9Ln6Fbc.jpg            [27, 878, 53]  1201734
# 1   False  /8rpDcsfLJypbO6vREc0547VKqEv.jpg            [878, 12, 28]    76600
# 2   False  /obKmfNexgL4ZP5cAmzdL4KbHHYX.jpg                 [12, 14]      673
# 3   False  /xAAYm7bUC5LnAj2Hs2hePOMHh2z.jpg                     [35]  1251687
# 4   False  /sRvXNDItGlWCqtO3j6wks52FmbD.jpg  [16, 35, 14, 12, 10751]      808
# 5   False  /9iRRfMZbnpgHDdKi2lczGGYZXDo.jpg          [12, 10751, 14]      411
# 6   False  /hZVIwxi6kK4KnpVPEWwdhG0cMM5.jpg               [9648, 53]  1012148
# 7   False  /xEZx8PvUz8OFmQMtSBiT5WgfYpa.jpg                     [18]  1029244
# 8   False  /fm6KqXpk3M2HVveHwCrBSSBaO0V.jpg                 [18, 36]   872585
# 9   False  /ncr6KR7bBF8cps6yZKiTAwClpn1.jpg          [14, 35, 10751]    10439
# 10  False  /iGdHtZBjpBkmSAgkvUeniIfI8ME.jpg                 [35, 12]   346698
# ...

# %%
df.drop_duplicates(subset=['original_title'], inplace=True)

# %%
df.drop(df['genre_ids']!= 28)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6448\3001906553.py in <module>
# ----> 1 df.drop(df['genre_ids']!= 28)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
#    4959             axis=axis,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20 entries, 0 to 19
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   adult              20 non-null     bool
#  1   backdrop_path      20 non-null     object
#  2   genre_ids          20 non-null     object
#  3   id                 20 non-null     int64
#  4   original_language  20 non-null     object
#  5   original_title     20 non-null     object
#  6   overview           20 non-null     object
#  7   popularity         20 non-null     float64
#  8   poster_path        20 non-null     object
#  9   release_date       20 non-null     object
#  10  title              20 non-null     object
#  11  video              20 non-null     bool
#  12  vote_average       20 non-null     float64
#  13  vote_count         20 non-null     int64
#  14  genre              20 non-null     object
# dtypes: bool(2), float64(2), int64(2), object(9)
# ...
