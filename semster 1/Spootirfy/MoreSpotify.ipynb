# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("spotify_songs.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32833 entries, 0 to 32832
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   track_id                  32833 non-null  object
#  1   track_name                32828 non-null  object
#  2   track_artist              32828 non-null  object
#  3   track_popularity          32833 non-null  int64
#  4   track_album_id            32833 non-null  object
#  5   track_album_name          32828 non-null  object
#  6   track_album_release_date  32833 non-null  object
#  7   playlist_name             32833 non-null  object
#  8   playlist_id               32833 non-null  object
#  9   playlist_genre            32833 non-null  object
#  10  playlist_subgenre         32833 non-null  object
#  11  danceability              32833 non-null  float64
#  12  energy                    32833 non-null  float64
# ...

# %%
sns.histplot(data=df, x="track_popularity", bins='auto')
# Out:
# <AxesSubplot:xlabel='track_popularity', ylabel='Count'>

# %%
summary = {
    "Max": df["track_popularity"].max(),
    "Q3": df["track_popularity"].quantile(0.75),
    "Median": df["track_popularity"].median(),
    "Q1": df["track_popularity"].quantile(0.25),
    "Min":df["track_popularity"].min()
}
summary
# Out:
# {'Max': 100, 'Q3': 62.0, 'Median': 45.0, 'Q1': 24.0, 'Min': 0}

# %%
sns.boxplot(data=df, x="track_popularity")
# Out:
# <AxesSubplot:xlabel='track_popularity'>

# %% [markdown]
# # Distribution of Popularity
# ## The shape of our popularity distribution is close to a symmetric, normal, bell curve.
# ## However, there is a lot of data collected in our very low scores, suggesting there are a lot of songs with low popularity scores.
# ## This is evidenced by our minimum value being 0! The median score is 45, which is less than half the range in our distribution.

# %%
def avg(col):
    average = col.mean()
    return average

# %%
avg(df["tempo"])
# Out:
# 120.88113154448297

# %%
def standard_deviation(dataframe, column):
    std = dataframe[column].std()
    return std
y = standard_deviation(df, "danceability")

# %%
sns.histplot(data=df, x="danceability", bins=50)
# Out:
# <AxesSubplot:xlabel='danceability', ylabel='Count'>

# %%
x = df["danceability"].mean()

# %%
print("A majority of songs fall within: ", (x+y), "and", (x-y))
# Out:
# A majority of songs fall within:  0.7999348407473437 and 0.5097641998520415

# %%
df
# Out:
#                      track_id  \
# 0      6f807x0ima9a1j3VPbc7VN
# 1      0r7CVbZTWZgbTCYdfa2P31
# 2      1z1Hg7Vb0AhHDiEmnDE79l
# 3      75FpbthrwQmzHlBJLuGdC7
# 4      1e8PAfcKUYoKkxPhrHqw4x
# ...                       ...
# 32828  7bxnKAamR3snQ1VGLuVfC1
# 32829  5Aevni09Em4575077nkWHz
# 32830  7ImMqPP3Q1yfUHvsdn7wEo
# 32831  2m69mhnfQ1Oq6lGtXuYhgX
# 32832  29zWqhca3zt5NsckZqDf6c
#
#                                               track_name      track_artist  \
# 0      I Don't Care (with Justin Bieber) - Loud Luxur...        Ed Sheeran
# 1                        Memories - Dillon Francis Remix          Maroon 5
# 2                        All the Time - Don Diablo Remix      Zara Larsson
# 3                      Call You Mine - Keanu Silva Remix  The Chainsmokers
# 4                Someone You Loved - Future Humans Remix     Lewis Capaldi
# ...                                                  ...               ...
# ...

# %%
df[df['track_popularity']==100]
# Out:
#                      track_id    track_name track_artist  track_popularity  \
# 1551   2XU0oxnq2qxCpomAAuJY8K  Dance Monkey  Tones and I               100
# 20091  2XU0oxnq2qxCpomAAuJY8K  Dance Monkey  Tones and I               100
#
#                track_album_id                             track_album_name  \
# 1551   0UywfDKYlyiu1b38DRrzYD  Dance Monkey (Stripped Back) / Dance Monkey
# 20091  0UywfDKYlyiu1b38DRrzYD  Dance Monkey (Stripped Back) / Dance Monkey
#
#       track_album_release_date  \
# 1551                2019-10-17
# 20091               2019-10-17
#
#                                            playlist_name  \
# 1551   post-teen alternative, indie, pop (large variety)
# 20091                          Global Top 50 | 2020 Hits
#
#                   playlist_id playlist_genre  ... key  loudness  mode  \
# 1551   1y42gwI5cuwjBslPyQNfqb            pop  ...   6      -6.4     0
# 20091  1KNl4AYfgZtOVm9KHkhPTF          latin  ...   6      -6.4     0
#
# ...

# %% [markdown]
# ***no it does not deserve a populatiry of 100 it kinda sucks my evidences is my ears***

# %%
sns.histplot(data=df, x="loudness", bins='auto')
# Out:
# <AxesSubplot:xlabel='loudness', ylabel='Count'>

# %%
df[df['loudness']<-40]
# Out:
#                      track_id       track_name          track_artist  \
# 17010  28ilcqErfNjitJ7T3byHoX  Peaceful Forest  The Sleep Specialist
#
#        track_popularity          track_album_id          track_album_name  \
# 17010                51  3TRoUn8OKRVUcbprXmyGgj  Jungle And Forest Sounds
#
#       track_album_release_date    playlist_name             playlist_id  \
# 17010               2017-01-09  Tropical Nights  37i9dQZF1DX0ES2mnOVvai
#
#       playlist_genre  ... key  loudness  mode  speechiness  acousticness  \
# 17010          latin  ...   7   -46.448     0       0.0542          0.88
#
#        instrumentalness  liveness  valence    tempo  duration_ms
# 17010             0.613     0.184   0.0122  116.884       181204
#
# [1 rows x 23 columns]

# %%
summary = {
    "Max": df["loudness"].max(),
    "Q3": df["loudness"].quantile(0.75),
    "Median": df["loudness"].median(),
    "Q1": df["loudness"].quantile(0.25),
    "Min":df["loudness"].min()
}
summary
# Out:
# {'Max': 1.275, 'Q3': -4.645, 'Median': -6.166, 'Q1': -8.171, 'Min': -46.448}

# %%
sd=df['loudness'].std()
sd
# Out:
# 2.9884363863324013

# %% [markdown]
# pear deck question
#
# most songs dont go over -4 loudness

# %%
dfp= df[df['playlist_genre']=="pop"]

# %%
dfr= df[df['playlist_genre']=="rap"]

# %%
sns.histplot(data=dfp, x="speechiness", bins=50)
sns.histplot(data=dfr, x="speechiness",color='red', bins=50)
# Out:
# <AxesSubplot:xlabel='speechiness', ylabel='Count'>

# %%
dfpm=dfp['speechiness'].mean()
dfrm=dfr['speechiness'].mean()
print("pop",dfpm,"rap",dfrm)
# Out:
# pop 0.07399126566188474 rap 0.1975058823529417

# %% [markdown]
# on avarage rap music is more speechy than pop music more specificly the avarage speecheness score of rap music in 0.1975 and the avarage for pop music is 0.07399
