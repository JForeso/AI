# %%
import pandas as pd
data = pd.read_csv("cats.csv")

# %%
data.head()
# Out:
#    Unnamed: 0          Breed  Age (Years)  Weight (kg)          Color  Gender  \
# 0           0   Egyptian Mau           12            7          White    Male
# 1           1  Scottish Fold           17            8  Tortoiseshell    Male
# 2           2         Sphynx            9            9         Orange    Male
# 3           3       Oriental            6            7           Gray  Female
# 4           4       Savannah           14            7  Tortoiseshell  Female
#
#     ID
# 0  181
# 1  907
# 2  732
# 3  464
# 4  451

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Breed', 'Age (Years)', 'Weight (kg)', 'Color', 'Gender',
#        'ID'],
#       dtype='object')

# %%
data
# Out:
#      Unnamed: 0          Breed  Age (Years)  Weight (kg)          Color  \
# 0             0   Egyptian Mau           12            7          White
# 1             1  Scottish Fold           17            8  Tortoiseshell
# 2             2         Sphynx            9            9         Orange
# 3             3       Oriental            6            7           Gray
# 4             4       Savannah           14            7  Tortoiseshell
# ..          ...            ...          ...          ...            ...
# 995         995     Abyssinian           18            3          Black
# 996         996        Burmese            4            5        Pointed
# 997         997        Persian           19            9          Cream
# 998         998        Persian           17            3        Bicolor
# 999         999           Manx           18            8          Black
#
#      Gender   ID
# 0      Male  181
# 1      Male  907
# 2      Male  732
# 3    Female  464
# 4    Female  451
# ..      ...  ...
# 995  Female  347
# 996  Female  339
# 997    Male  659
# 998  Female  124
# 999    Male  226
#
# [1000 rows x 7 columns]

# %%
data.drop(['Unnamed: 0'], inplace= True, axis=1)

# %%
data
# Out:
#              Breed  Age (Years)  Weight (kg)          Color  Gender   ID
# 0     Egyptian Mau           12            7          White    Male  181
# 1    Scottish Fold           17            8  Tortoiseshell    Male  907
# 2           Sphynx            9            9         Orange    Male  732
# 3         Oriental            6            7           Gray  Female  464
# 4         Savannah           14            7  Tortoiseshell  Female  451
# ..             ...          ...          ...            ...     ...  ...
# 995     Abyssinian           18            3          Black  Female  347
# 996        Burmese            4            5        Pointed  Female  339
# 997        Persian           19            9          Cream    Male  659
# 998        Persian           17            3        Bicolor  Female  124
# 999           Manx           18            8          Black    Male  226
#
# [1000 rows x 6 columns]

# %%
data.iloc[98]
# Out:
# Breed          Maine Coon
# Age (Years)             9
# Weight (kg)             5
# Color                Blue
# Gender             Female
# ID                    590
# Name: 98, dtype: object

# %%
new_row = {'Breed': 'tabby', 'Age (Years)': 3.0, 'Weight (kg)': 5.0, 'Color': 'orange', 'Gender': 'Male', 'ID': 'Zuko' }
data=data.append(new_row, ignore_index=True)
# Out:
# C:\Users\jforesoii\AppData\Local\Temp\ipykernel_8964\845866390.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data=data.append(new_row, ignore_index=True)

# %%
data.iloc[1000]
# Out:
# Breed           tabby
# Age (Years)       3.0
# Weight (kg)       5.0
# Color          orange
# Gender           Male
# ID               Zuko
# Name: 1000, dtype: object

# %%
data
# Out:
#               Breed  Age (Years)  Weight (kg)          Color  Gender    ID
# 0      Egyptian Mau         12.0          7.0          White    Male   181
# 1     Scottish Fold         17.0          8.0  Tortoiseshell    Male   907
# 2            Sphynx          9.0          9.0         Orange    Male   732
# 3          Oriental          6.0          7.0           Gray  Female   464
# 4          Savannah         14.0          7.0  Tortoiseshell  Female   451
# ...             ...          ...          ...            ...     ...   ...
# 996         Burmese          4.0          5.0        Pointed  Female   339
# 997         Persian         19.0          9.0          Cream    Male   659
# 998         Persian         17.0          3.0        Bicolor  Female   124
# 999            Manx         18.0          8.0          Black    Male   226
# 1000          tabby          3.0          5.0         orange    Male  Zuko
#
# [1001 rows x 6 columns]

# %%
data.loc[1000]['Breed']
# Out:
# 'tabby'

# %%
data['Weight (lbs)']=data['Weight (kg)']* 2.205

# %%
data
# Out:
#               Breed  Age (Years)  Weight (kg)          Color  Gender    ID  \
# 0      Egyptian Mau         12.0          7.0          White    Male   181
# 1     Scottish Fold         17.0          8.0  Tortoiseshell    Male   907
# 2            Sphynx          9.0          9.0         Orange    Male   732
# 3          Oriental          6.0          7.0           Gray  Female   464
# 4          Savannah         14.0          7.0  Tortoiseshell  Female   451
# ...             ...          ...          ...            ...     ...   ...
# 996         Burmese          4.0          5.0        Pointed  Female   339
# 997         Persian         19.0          9.0          Cream    Male   659
# 998         Persian         17.0          3.0        Bicolor  Female   124
# 999            Manx         18.0          8.0          Black    Male   226
# 1000          tabby          3.0          5.0         orange    Male  Zuko
#
#       Weight (lbs)
# 0           15.435
# 1           17.640
# 2           19.845
# 3           15.435
# 4           15.435
# ...            ...
# 996         11.025
# 997         19.845
# 998          6.615
# 999         17.640
# 1000        11.025
#
# [1001 rows x 7 columns]
