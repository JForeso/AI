# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_json('games.json')

# %%
df
# Out:
#             ID                    name  release_date estimated_owners  \
# 0        20200        Galactic Bowling  Oct 21, 2008        0 - 20000
# 1       655370            Train Bandit  Oct 12, 2017        0 - 20000
# 2      1732930            Jolt Project  Nov 17, 2021        0 - 20000
# 3      1355720                Henosis™  Jul 23, 2020        0 - 20000
# 4      1139950   Two Weeks in Painland   Feb 3, 2020        0 - 20000
# ...        ...                     ...           ...              ...
# 97405  3080940  Femdom Game World: Mom  Aug 22, 2024        0 - 20000
# 97406  2593970             Blocky Farm  Aug 30, 2024            0 - 0
# 97407  3137150    Infiltrate & Extract  Aug 30, 2024            0 - 0
# 97408  3124670       Escape The Garage  Aug 29, 2024            0 - 0
# 97409  3054200              Lober Lobe  Aug 30, 2024            0 - 0
#
#        peak_ccu  required_age  price  dlc_count  \
# 0             0             0  19.99          0
# ...

# %%
df[df['ID']==22380]
# Out:
#          ID                name  release_date   estimated_owners  peak_ccu  \
# 1025  22380  Fallout: New Vegas  Oct 19, 2010  2000000 - 5000000      5776
#
#       required_age  price  dlc_count  \
# 1025            16   9.99          0
#
#                                        main_description  \
# 1025  Welcome to Vegas. New Vegas. It’s the kind of ...
#
#                                     supported_languages  ...  \
# 1025  ['English', 'French', 'German', 'Italian', 'Sp...  ...
#
#      average_playtime_forever average_playtime_2weeks median_playtime_forever  \
# 1025                     3044                     112                     976
#
#      packages              developers          publishers  \
# 1025      153  Obsidian Entertainment  Bethesda Softworks
#
#                                              categories      genres  \
# 1025  Single-player,Steam Achievements,Partial Contr...  Action,RPG
#
#                                                    tags  \
# ...

# %% [markdown]
# T

# %%
df[df['name']=='Call of Duty']
# Out:
#            ID                                              name  release_date  \
# 136      7940                  Call of Duty® 4: Modern Warfare®  Nov 12, 2007
# 16436  209160                             Call of Duty®: Ghosts  Mar 25, 2014
# 41916  209170                             Call of Duty®: Ghosts  Mar 25, 2014
# 49956   10190           Call of Duty®: Modern Warfare® 2 (2009)  Nov 11, 2009
# 50457   10180           Call of Duty®: Modern Warfare® 2 (2009)  Nov 11, 2009
# 51173    2620                                     Call of Duty®  Oct 13, 2006
# 53884    2630                                   Call of Duty® 2  Oct 13, 2006
# 55842  255163  Call of Duty®: Ghosts - Digital Hardened Edition   Nov 4, 2013
# 57436  292730                   Call of Duty®: Infinite Warfare   Nov 3, 2016
#
#          estimated_owners  peak_ccu  required_age  price  dlc_count  \
# 136     1000000 - 2000000       495            17   9.99          0
# ...

# %%
df[df['name'].str.contains('Call of Duty',na=False)]
# Out:
#             ID                                              name  \
# 136       7940                  Call of Duty® 4: Modern Warfare®
# 3073     42710                          Call of Duty®: Black Ops
# 7629    393080         Call of Duty®: Modern Warfare® Remastered
# 8176    202990                       Call of Duty®: Black Ops II
# 15118   311210                      Call of Duty®: Black Ops III
# 16436   209160                             Call of Duty®: Ghosts
# 20805     2640                    Call of Duty: United Offensive
# 21930   209650    Call of Duty®: Advanced Warfare - Gold Edition
# 22085   209660    Call of Duty®: Advanced Warfare - Gold Edition
# 24094   476600                               Call of Duty®: WWII
# 27498    10090                        Call of Duty: World at War
# 29125    42680                  Call of Duty®: Modern Warfare® 3
# 29670    42700                          Call of Duty®: Black Ops
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 97410 entries, 0 to 97409
# Data columns (total 38 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        97410 non-null  int64
#  1   name                      97404 non-null  object
#  2   release_date              97410 non-null  object
#  3   estimated_owners          97410 non-null  object
#  4   peak_ccu                  97410 non-null  int64
#  5   required_age              97410 non-null  int64
#  6   price                     97410 non-null  float64
#  7   dlc_count                 97410 non-null  int64
#  8   main_description          92540 non-null  object
#  9   supported_languages       97410 non-null  object
#  10  full_audio_languages      97410 non-null  object
#  11  reviews                   10125 non-null  object
#  12  header_image              97410 non-null  object
# ...

# %%
sns.scatterplot(data=df, x=df['metacritic_score'], y=df['price'], )
# Out:
# <AxesSubplot:xlabel='metacritic_score', ylabel='price'>

# %% [markdown]
# i would not say there is a corlation if there is its to hard to see from the mass of the data set i guess if a game is under 100 dollors its more likely to have a higher score

# %%
sns.scatterplot(data=df, x=df['price'], y=df['estimated_owners'], )
# Out:
# <AxesSubplot:xlabel='price', ylabel='estimated_owners'>
