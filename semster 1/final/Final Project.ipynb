# %% [markdown]
# # Choose a Data Set
#
# You can choose to analyze any data that you would like! Remember, you need 1000 rows of non-null data in order to get 5 points for the "Data" criteria of my [rubric](https://docs.google.com/document/d/1s3wllcF3LLnytxwD8mZ-BCypXKnfaahnizWGNojT-B4/edit?usp=sharing). Consider looking at [Kaggle](https://www.kaggle.com/datasets) or [free APIs](https://free-apis.github.io/#/browse) for datasets of this size. Alternatively, you can scrape the web to make your own dataset! :D
#
# Once you have chosen your dataset, please read your data into a dataframe and call `.info()` below. If you don't call `info` I will give you 0 points for the first criteria described on the [rubric](https://docs.google.com/document/d/1s3wllcF3LLnytxwD8mZ-BCypXKnfaahnizWGNojT-B4/edit?usp=sharing).

# %%
# Read data into a dataframe and call info()
    # Example call:
    # df = pd.DataFrame({"A":[1, 2, 3], "B":[4, 5, 6]})
    # df.info()

# %% [markdown]
# # My Question

# %% [markdown]
# ### is there a corilation between the number of people reviewing a game and the games rateings

# %% [markdown]
# # My Analysis

# %%
# Analyze here

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import requests
from bs4 import BeautifulSoup
import random

# %%
df = pd.DataFrame()
count=0
page = 1
while count != 30:
    count+=1
    page+=1
    url= 'https://api.rawg.io/api/games?key=026c1e70881c4308a3c3d8ca1a870c5d&page_size=40&page='+ str(page)
    r = requests.get(url)
    data = r.json()
    df = df.append(pd.DataFrame(data["results"]), ignore_index=True)
# Out:
# C:\Users\jforesoii\AppData\Local\Temp\ipykernel_28976\2404168304.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data["results"]), ignore_index=True)
# C:\Users\jforesoii\AppData\Local\Temp\ipykernel_28976\2404168304.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data["results"]), ignore_index=True)
# C:\Users\jforesoii\AppData\Local\Temp\ipykernel_28976\2404168304.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data["results"]), ignore_index=True)
# C:\Users\jforesoii\AppData\Local\Temp\ipykernel_28976\2404168304.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data["results"]), ignore_index=True)
# C:\Users\jforesoii\AppData\Local\Temp\ipykernel_28976\2404168304.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data["results"]), ignore_index=True)
# C:\Users\jforesoii\AppData\Local\Temp\ipykernel_28976\2404168304.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data["results"]), ignore_index=True)
# C:\Users\jforesoii\AppData\Local\Temp\ipykernel_28976\2404168304.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data["results"]), ignore_index=True)
# C:\Users\jforesoii\AppData\Local\Temp\ipykernel_28976\2404168304.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data["results"]), ignore_index=True)
# C:\Users\jforesoii\AppData\Local\Temp\ipykernel_28976\2404168304.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data["results"]), ignore_index=True)
# C:\Users\jforesoii\AppData\Local\Temp\ipykernel_28976\2404168304.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data["results"]), ignore_index=True)
# C:\Users\jforesoii\AppData\Local\Temp\ipykernel_28976\2404168304.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data["results"]), ignore_index=True)
# C:\Users\jforesoii\AppData\Local\Temp\ipykernel_28976\2404168304.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data["results"]), ignore_index=True)
# C:\Users\jforesoii\AppData\Local\Temp\ipykernel_28976\2404168304.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data["results"]), ignore_index=True)
# C:\Users\jforesoii\AppData\Local\Temp\ipykernel_28976\2404168304.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data["results"]), ignore_index=True)
# C:\Users\jforesoii\AppData\Local\Temp\ipykernel_28976\2404168304.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data["results"]), ignore_index=True)
# C:\Users\jforesoii\AppData\Local\Temp\ipykernel_28976\2404168304.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data["results"]), ignore_index=True)
# C:\Users\jforesoii\AppData\Local\Temp\ipykernel_28976\2404168304.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data["results"]), ignore_index=True)
# C:\Users\jforesoii\AppData\Local\Temp\ipykernel_28976\2404168304.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data["results"]), ignore_index=True)
# C:\Users\jforesoii\AppData\Local\Temp\ipykernel_28976\2404168304.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data["results"]), ignore_index=True)
# C:\Users\jforesoii\AppData\Local\Temp\ipykernel_28976\2404168304.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data["results"]), ignore_index=True)
# C:\Users\jforesoii\AppData\Local\Temp\ipykernel_28976\2404168304.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data["results"]), ignore_index=True)
# C:\Users\jforesoii\AppData\Local\Temp\ipykernel_28976\2404168304.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data["results"]), ignore_index=True)
# C:\Users\jforesoii\AppData\Local\Temp\ipykernel_28976\2404168304.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data["results"]), ignore_index=True)
# C:\Users\jforesoii\AppData\Local\Temp\ipykernel_28976\2404168304.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data["results"]), ignore_index=True)
# C:\Users\jforesoii\AppData\Local\Temp\ipykernel_28976\2404168304.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data["results"]), ignore_index=True)
# C:\Users\jforesoii\AppData\Local\Temp\ipykernel_28976\2404168304.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data["results"]), ignore_index=True)
# C:\Users\jforesoii\AppData\Local\Temp\ipykernel_28976\2404168304.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data["results"]), ignore_index=True)
# C:\Users\jforesoii\AppData\Local\Temp\ipykernel_28976\2404168304.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data["results"]), ignore_index=True)
# C:\Users\jforesoii\AppData\Local\Temp\ipykernel_28976\2404168304.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data["results"]), ignore_index=True)
# C:\Users\jforesoii\AppData\Local\Temp\ipykernel_28976\2404168304.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data["results"]), ignore_index=True)

# %%
df
# Out:
#           id                                slug  \
# 0       9767                       hollow-knight
# 1      19709             half-life-2-episode-two
# 2         41                   little-nightmares
# 3       4427                          bioshock-2
# 4      18080                           half-life
# ...      ...                                 ...
# 1195    2422            homefront-the-revolution
# 1196  650605                    cult-of-the-lamb
# 1197    9969  app-game-kit-easy-game-development
# 1198  388308                         overwatch-2
# 1199     431                         kings-quest
#
#                                      name    released    tba  \
# 0                           Hollow Knight  2017-02-23  False
# 1                Half-Life 2: Episode Two  2007-10-10  False
# 2                       Little Nightmares  2017-04-27  False
# 3                              BioShock 2  2010-02-09  False
# 4                               Half-Life  1998-11-08  False
# ...                                   ...         ...    ...
# 1195            Homefront: The Revolution  2016-05-17  False
# 1196                     Cult of the Lamb  2022-08-11  False
# 1197  App Game Kit: Easy Game Development  2014-11-21  False
# 1198                          Overwatch 2  2022-10-04  False
# 1199                         King's Quest  2015-07-28  False
#
#                                        background_image  rating  rating_top  \
# 0     https://media.rawg.io/media/games/4cf/4cfc6b7f...    4.41           5
# 1     https://media.rawg.io/media/games/198/1988a337...    4.45           5
# 2     https://media.rawg.io/media/games/8a0/8a02f84a...    4.04           4
# 3     https://media.rawg.io/media/games/157/15742f2f...    4.07           4
# 4     https://media.rawg.io/media/games/6c5/6c55e221...    4.37           5
# ...                                                 ...     ...         ...
# 1195  https://media.rawg.io/media/games/6eb/6eb5ed3b...    3.01           3
# 1196  https://media.rawg.io/media/games/ab8/ab8217a1...    4.14           4
# 1197  https://media.rawg.io/media/screenshots/49d/49...    1.75           1
# 1198  https://media.rawg.io/media/games/95a/95a10817...    3.14           3
# 1199  https://media.rawg.io/media/screenshots/058/05...    3.41           4
#
#                                                 ratings  ratings_count  ...  \
# 0     [{'id': 5, 'title': 'exceptional', 'count': 16...           2540  ...
# 1     [{'id': 5, 'title': 'exceptional', 'count': 11...           1945  ...
# 2     [{'id': 4, 'title': 'recommended', 'count': 85...           1552  ...
# 3     [{'id': 4, 'title': 'recommended', 'count': 10...           1903  ...
# 4     [{'id': 5, 'title': 'exceptional', 'count': 13...           2310  ...
# ...                                                 ...            ...  ...
# 1195  [{'id': 3, 'title': 'meh', 'count': 156, 'perc...            339  ...
# 1196  [{'id': 4, 'title': 'recommended', 'count': 21...            368  ...
# 1197  [{'id': 1, 'title': 'skip', 'count': 78, 'perc...            119  ...
# 1198  [{'id': 3, 'title': 'meh', 'count': 123, 'perc...            328  ...
# 1199  [{'id': 4, 'title': 'recommended', 'count': 10...            226  ...
#
#       saturated_color  dominant_color  \
# 0              0f0f0f          0f0f0f
# 1              0f0f0f          0f0f0f
# 2              0f0f0f          0f0f0f
# 3              0f0f0f          0f0f0f
# 4              0f0f0f          0f0f0f
# ...               ...             ...
# 1195           0f0f0f          0f0f0f
# 1196           0f0f0f          0f0f0f
# 1197           0f0f0f          0f0f0f
# 1198           0f0f0f          0f0f0f
# 1199           0f0f0f          0f0f0f
#
#                                               platforms  \
# 0     [{'platform': {'id': 18, 'name': 'PlayStation ...
# 1     [{'platform': {'id': 21, 'name': 'Android', 's...
# 2     [{'platform': {'id': 3, 'name': 'iOS', 'slug':...
# 3     [{'platform': {'id': 18, 'name': 'PlayStation ...
# 4     [{'platform': {'id': 106, 'name': 'Dreamcast',...
# ...                                                 ...
# 1195  [{'platform': {'id': 1, 'name': 'Xbox One', 's...
# 1196  [{'platform': {'id': 5, 'name': 'macOS', 'slug...
# 1197  [{'platform': {'id': 5, 'name': 'macOS', 'slug...
# 1198  [{'platform': {'id': 186, 'name': 'Xbox Series...
# 1199  [{'platform': {'id': 1, 'name': 'Xbox One', 's...
#
#                                        parent_platforms  \
# 0     [{'platform': {'id': 1, 'name': 'PC', 'slug': ...
# 1     [{'platform': {'id': 1, 'name': 'PC', 'slug': ...
# 2     [{'platform': {'id': 1, 'name': 'PC', 'slug': ...
# 3     [{'platform': {'id': 1, 'name': 'PC', 'slug': ...
# 4     [{'platform': {'id': 1, 'name': 'PC', 'slug': ...
# ...                                                 ...
# 1195  [{'platform': {'id': 1, 'name': 'PC', 'slug': ...
# 1196  [{'platform': {'id': 1, 'name': 'PC', 'slug': ...
# 1197  [{'platform': {'id': 1, 'name': 'PC', 'slug': ...
# 1198  [{'platform': {'id': 1, 'name': 'PC', 'slug': ...
# 1199  [{'platform': {'id': 1, 'name': 'PC', 'slug': ...
#
#                                                  genres  \
# 0     [{'id': 4, 'name': 'Action', 'slug': 'action',...
# 1     [{'id': 4, 'name': 'Action', 'slug': 'action',...
# 2     [{'id': 4, 'name': 'Action', 'slug': 'action',...
# 3     [{'id': 4, 'name': 'Action', 'slug': 'action',...
# 4     [{'id': 4, 'name': 'Action', 'slug': 'action',...
# ...                                                 ...
# 1195  [{'id': 4, 'name': 'Action', 'slug': 'action',...
# 1196  [{'id': 4, 'name': 'Action', 'slug': 'action',...
# 1197  [{'id': 34, 'name': 'Educational', 'slug': 'ed...
# 1198  [{'id': 4, 'name': 'Action', 'slug': 'action',...
# 1199  [{'id': 4, 'name': 'Action', 'slug': 'action',...
#
#                                                  stores  clip  \
# 0     [{'id': 10646, 'store': {'id': 1, 'name': 'Ste...  None
# 1     [{'id': 22130, 'store': {'id': 1, 'name': 'Ste...  None
# 2     [{'id': 985929, 'store': {'id': 4, 'name': 'Ap...  None
# 3     [{'id': 79405, 'store': {'id': 4, 'name': 'App...  None
# 4     [{'id': 20250, 'store': {'id': 1, 'name': 'Ste...  None
# ...                                                 ...   ...
# 1195  [{'id': 2535, 'store': {'id': 3, 'name': 'Play...  None
# 1196  [{'id': 645838, 'store': {'id': 1, 'name': 'St...  None
# 1197  [{'id': 10873, 'store': {'id': 1, 'name': 'Ste...  None
# 1198  [{'id': 962743, 'store': {'id': 1, 'name': 'St...  None
# 1199  [{'id': 435, 'store': {'id': 2, 'name': 'Xbox ...  None
#
#                                                    tags  \
# 0     [{'id': 31, 'name': 'Singleplayer', 'slug': 's...
# 1     [{'id': 31, 'name': 'Singleplayer', 'slug': 's...
# 2     [{'id': 31, 'name': 'Singleplayer', 'slug': 's...
# 3     [{'id': 31, 'name': 'Singleplayer', 'slug': 's...
# 4     [{'id': 31, 'name': 'Singleplayer', 'slug': 's...
# ...                                                 ...
# 1195  [{'id': 31, 'name': 'Singleplayer', 'slug': 's...
# 1196  [{'id': 31, 'name': 'Singleplayer', 'slug': 's...
# 1197  [{'id': 45, 'name': '2D', 'slug': '2d', 'langu...
# 1198  [{'id': 40847, 'name': 'Steam Achievements', '...
# 1199  [{'id': 31, 'name': 'Singleplayer', 'slug': 's...
#
#                                             esrb_rating  \
# 0     {'id': 2, 'name': 'Everyone 10+', 'slug': 'eve...
# 1         {'id': 4, 'name': 'Mature', 'slug': 'mature'}
# 2                                                  None
# 3                                                  None
# 4         {'id': 4, 'name': 'Mature', 'slug': 'mature'}
# ...                                                 ...
# 1195      {'id': 4, 'name': 'Mature', 'slug': 'mature'}
# 1196                                               None
# 1197                                               None
# 1198          {'id': 3, 'name': 'Teen', 'slug': 'teen'}
# 1199  {'id': 2, 'name': 'Everyone 10+', 'slug': 'eve...
#
#                                       short_screenshots
# 0     [{'id': -1, 'image': 'https://media.rawg.io/me...
# 1     [{'id': -1, 'image': 'https://media.rawg.io/me...
# 2     [{'id': -1, 'image': 'https://media.rawg.io/me...
# 3     [{'id': -1, 'image': 'https://media.rawg.io/me...
# 4     [{'id': -1, 'image': 'https://media.rawg.io/me...
# ...                                                 ...
# 1195  [{'id': -1, 'image': 'https://media.rawg.io/me...
# 1196  [{'id': -1, 'image': 'https://media.rawg.io/me...
# 1197  [{'id': -1, 'image': 'https://media.rawg.io/me...
# 1198  [{'id': -1, 'image': 'https://media.rawg.io/me...
# 1199  [{'id': -1, 'image': 'https://media.rawg.io/me...
#
# [1200 rows x 29 columns]

# %%
df["released"]= pd.to_datetime(df['released'])

# %%
sns.regplot(data=df, x=df['rating'], y=df['ratings_count'],color='red' )
# Out:
# <AxesSubplot:xlabel='rating', ylabel='ratings_count'>

# %%
correlation_matrix = df.corr(method='pearson')

print(correlation_matrix)
# Out:
#                           id       tba    rating  rating_top  ratings_count  \
# id                  1.000000  0.062035  0.088051    0.053691      -0.101794
# tba                 0.062035  1.000000  0.011453    0.038972      -0.022539
# rating              0.088051  0.011453  1.000000    0.821065       0.505937
# rating_top          0.053691  0.038972  0.821065    1.000000       0.387990
# ratings_count      -0.101794 -0.022539  0.505937    0.387990       1.000000
# reviews_text_count  0.174869  0.014731  0.452998    0.358424       0.712121
# added              -0.114927 -0.028001  0.277485    0.238230       0.825569
# metacritic          0.050670       NaN  0.614341    0.498955       0.361133
# playtime            0.079410  0.774929  0.181854    0.154405       0.211448
# suggestions_count  -0.036134  0.010531  0.090803    0.057969       0.172476
# reviews_count      -0.097885 -0.022189  0.507408    0.389183       0.999946
#
#                     reviews_text_count     added  metacritic  playtime  \
# id                            0.174869 -0.114927    0.050670  0.079410
# tba                           0.014731 -0.028001         NaN  0.774929
# rating                        0.452998  0.277485    0.614341  0.181854
# rating_top                    0.358424  0.238230    0.498955  0.154405
# ratings_count                 0.712121  0.825569    0.361133  0.211448
# reviews_text_count            1.000000  0.506972    0.300732  0.240018
# added                         0.506972  1.000000    0.246685  0.102539
# metacritic                    0.300732  0.246685    1.000000  0.201340
# playtime                      0.240018  0.102539    0.201340  1.000000
# suggestions_count             0.099126  0.139343   -0.016871  0.098989
# reviews_count                 0.719004  0.824324    0.361557  0.212563
#
#                     suggestions_count  reviews_count
# id                          -0.036134      -0.097885
# tba                          0.010531      -0.022189
# rating                       0.090803       0.507408
# rating_top                   0.057969       0.389183
# ratings_count                0.172476       0.999946
# reviews_text_count           0.099126       0.719004
# added                        0.139343       0.824324
# metacritic                  -0.016871       0.361557
# playtime                     0.098989       0.212563
# suggestions_count            1.000000       0.172068
# reviews_count                0.172068       1.000000

# %%
# Out:
#              Title
# 0    The Iron Heel
# 84   The Iron Heel
# 483  The Iron Heel
# 567  The Iron Heel
# 966  The Iron Heel

# %% [markdown]
# # My Answer

# %% [markdown]
# ### there is a slight corilation of 0.505 between the the rating and the number of reviewers
